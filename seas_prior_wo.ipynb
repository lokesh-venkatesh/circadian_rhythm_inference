# %% [markdown]
# # Training Run - Seasonal Prior & phase shifted inputs

# %% [markdown]
# #### Importing Libraries:

# %%
import subprocess
import os
import sys
import argparse
import shutil
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap.umap_ as umap
import os

from utils import *

# %% [markdown]
# ### Config

# %%
# define constants
INPUT_SIZE = 64*24
DEGREE = 3
LATENT_SIZE = 4*24
gnrt_start = '1970-01-01 00:00:00'
gnrt_end = '2020-12-31 16:00:00'

# Parameters
input_shape = INPUT_SIZE
latent_dim = None
latent_filter = 20
interim_filters = 20

# training hyperparameters
learning_rate = 0.001
epochs = 500
batch_size = 32

prior_dist_type = 'Seasonal'
activate_phase_shift = False

os.makedirs('results', exist_ok=True)
results_directory = f'results/training_run_{prior_dist_type}_prior_{activate_phase_shift}_phase_shift_{epochs}_epochs'

# %% [markdown]
# ### Data Processing

# %%
# %matplotlib notebook

os.makedirs('data/processed', exist_ok=True)
os.makedirs('images', exist_ok=True)

set_seed(42)
df_list = []
for year in range(1970, 2021, 3):
    ds = xr.open_dataset(f'data/raw/phoenix/t2m_{year}_{year+2}/data_stream-oper_stepType-instant.nc')
    df = pd.DataFrame(index=ds['valid_time'], data=ds['t2m'][:, 0, 0])
    df.index = pd.to_datetime(df.index)
    df_list.append(df)

df = pd.concat(df_list)
df.columns = ['Observed']

# convert Kelvin to Celsius
df.Observed = df.Observed - 273.15
df_mst = df.copy()
df_mst.index = df_mst.index.shift(-7, freq='h')
df_mst = df_mst.iloc[7:]

# Calculate the slope of the temperature trend across yearly averages
df_yearly = df_mst.resample('YS').mean()
slope = np.polyfit(df_yearly.index.year, df_yearly['Observed'], 1)[0]
# Add climate adjusted data to dataframe
df_mst['Climate Adjusted'] = df_mst['Observed'] - slope*(df_mst.index.year-2020)

df_yearly = df_mst.resample('YS').mean()
df_yearly.plot()
plt.title('Annual Average Temperature in Phoenix')
plt.ylabel('Temperature (°C)')
plt.xlabel('Year')
plt.gca().get_lines()[1].set_linestyle('--')
plt.gca().get_lines()[0].set_color('orange')
plt.gca().get_lines()[1].set_color('red')
plt.legend()
plt.savefig('images/long_term_trend.png', dpi=300)
plt.close()

# Save the processed data
df_mst.to_csv('data/processed/observed_time_series.csv')

offset = round(df_mst['Climate Adjusted'].mean(), 8)
print('offset: ', offset)
scale = round(df_mst['Climate Adjusted'].std(), 8)
print('scale:  ', scale)
dft = (df_mst['Climate Adjusted']-offset)/scale

data_params = pd.Series({'offset': offset, 'scale': scale}, name='values')
data_params.to_csv('data/data_params.csv')

values = dft.values.squeeze()  # (T,) shape if single column
timestamps = dft.index

# Parameters
window_size = INPUT_SIZE  # 64 days
hop_size = int(window_size/4)     # 16 days
total_hours = len(values)

# Generate overlapping windows
X = []
index = []

while True:
    start = len(X)*hop_size
    start = max(0, min(start, total_hours - window_size)) # ensure within bounds
    end = start + window_size
    if end > total_hours:
        break
    X.append(values[start:end])
    index.append(timestamps[start])
    if end == total_hours:
        break

X = np.array(X)  # Shape: (num_chunks, window_size)
index = pd.to_datetime(index)

# Create DataFrame with timestamp index
dft_reshaped = pd.DataFrame(data=X, index=index)

# Keep only rows where the index month is January
# dft_reshaped = dft_reshaped[dft_reshaped.index.month.isin([1])]

# Shuffle rows reproducibly
dft_reshaped = dft_reshaped.sample(frac=1)

# Save to CSV
dft_reshaped.to_csv('data/processed/phoenix_64days.csv')
# Out:
# <div id='ec81e8de-021a-44c4-ad7a-44b2a4e1e0e3'></div>
# offset:  23.27571895
# scale:   9.89200131

# %% [markdown]
# ## Model

# %%
# import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

# Build the encoder
def build_encoder():
    inputs = layers.Input(shape=(input_shape,))
    x = layers.Reshape((-1, 1))(inputs)
    x = layers.Conv1D(interim_filters, 5, strides=3, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(2*latent_filter, 3, strides=2, padding='same')(x)
    z_mean = x[: ,:, :latent_filter]
    z_log_var = x[:, :, latent_filter:]
    z = Sampling()([z_mean, z_log_var])
    encoder = models.Model(inputs, [z_mean, z_log_var, z], name='encoder')
    return encoder

# Build the decoder
def build_decoder():
    latent_inputs = layers.Input(shape=(latent_dim, latent_filter))
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(latent_inputs)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(1, 5, strides=3, padding='same')(x)
    outputs = layers.Reshape((-1,))(x)
    decoder = models.Model(latent_inputs, outputs, name='decoder')
    return decoder

def build_seasonal_prior():
    seasonal_inputs = layers.Input(shape=(None, 2*DEGREE,))
    x = layers.Dense(2*latent_filter, use_bias=False)(seasonal_inputs)
    z_mean = x[:, :, :latent_filter]
    z_log_var = x[:, :, latent_filter:]
    z = Sampling()([z_mean, z_log_var])
    seasonal_prior = models.Model(seasonal_inputs, [z_mean, z_log_var, z], name='seasonal_prior')
    return seasonal_prior

class VAE(models.Model):
    def __init__(self, encoder, decoder, prior, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.prior = prior # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        self.noise_log_var = self.add_weight(name='var', shape=(1,), initializer='zeros', trainable=True)

    @tf.function
    def vae_loss(self, data):
        values = data[0]
        seasonal = data[1]
        z_mean, z_log_var, z = self.encoder(values)
        reconstructed = self.decoder(z)
        reconstruction_loss = -log_lik_normal_sum(values, reconstructed, self.noise_log_var)/INPUT_SIZE
        seasonal_z_mean, seasonal_z_log_var, _ = self.prior(seasonal) # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        kl_loss_z = kl_divergence_sum(z_mean, z_log_var, seasonal_z_mean, seasonal_z_log_var)/INPUT_SIZE # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        kl_loss_z = kl_divergence_standard_normal(z_mean, z_log_var) / INPUT_SIZE # Standard normal prior: mean=0, log_var=0 (=> std=1)
        return reconstruction_loss, kl_loss_z

    def train_step(self, data):
        with tf.GradientTape() as tape:
            reconstruction_loss, kl_loss_z = self.vae_loss(data)
            total_loss = reconstruction_loss + kl_loss_z
        
        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        
        return {'loss': total_loss}
    
    def test_step(self, data):
        reconstruction_loss, kl_loss_z = self.vae_loss(data)

        return {'loss': reconstruction_loss + kl_loss_z, 'recon': reconstruction_loss, 'kl': kl_loss_z}

    def call(self, inputs):
        _, _, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        return reconstructed

# %% [markdown]
# ## Training

# %%
os.makedirs('model', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

fourier = lambda x: np.stack(
    [np.sin(2*np.pi*i*x) for i in range(1, DEGREE+1)] + 
    [np.cos(2*np.pi*i*x) for i in range(1, DEGREE+1)], axis=-1)

starting_day = np.array([d.timetuple().tm_yday for d in data.index])[:, np.newaxis]
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)

training_ratio = 0.8
num_train = int(len(data)*training_ratio)

train = data.values[:num_train]
test = data.values[num_train:]
train_seasonal = seasonal_data[:num_train]
test_seasonal = seasonal_data[num_train:]

# convert to tensors
train_tensor = tf.convert_to_tensor(train, dtype=tf.float32)
test_tensor = tf.convert_to_tensor(test, dtype=tf.float32)
train_seasonal_tensor = tf.convert_to_tensor(train_seasonal, dtype=tf.float32)
test_seasonal_tensor = tf.convert_to_tensor(test_seasonal, dtype=tf.float32)

# building the model
encoder = build_encoder()
encoder.summary()
decoder = build_decoder()
decoder.summary()
seasonal_prior = build_seasonal_prior()
seasonal_prior.summary()

# Create the VAE model
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
optimizer = Adam(learning_rate=learning_rate)
vae.compile(optimizer=optimizer)

history = vae.fit(
    train_tensor, train_seasonal_tensor, 
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(test_tensor, test_seasonal_tensor),)

# Save model weights
_ = vae(train_tensor[:1])  # Call model once to build it
vae.save_weights('model/model_weights.weights.h5')

# Model reconstruction accuracy
print('noise emission sigma: ', np.exp(0.5*vae.noise_log_var)[0])

# Loss on validation data
recon_loss, kl_loss = vae.vae_loss((test_tensor, test_seasonal_tensor))
recon_loss = recon_loss.numpy()
kl_loss = kl_loss.numpy()
total_loss = recon_loss + kl_loss

# Save loss information as a dataframe
summary_df = pd.DataFrame({
    'Reconstruction loss': [recon_loss],
    'KL loss': [kl_loss],
    'Total loss': [total_loss]
})
summary_df.to_csv('data/train_summary.csv', index=False)

print('Reconstruction loss: ', recon_loss)
print('KL loss:             ', kl_loss)
print('Total loss:          ', total_loss)
# Out:
# WARNING:tensorflow:From C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1536)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1536, 1)   │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 512, 20)   │        120 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 256, 20)   │      1,220 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 128, 20)   │      1,220 │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 64, 20)    │      1,220 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 32, 20)    │      1,220 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 16, 40)    │      2,440 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 16, 20)    │          0 │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 16, 20)    │          0 │ conv1d_5[0][0]    │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 16, 20)    │          0 │ get_item[0][0],   │
# │                     │                   │            │ get_item_1[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,440 (29.06 KB)
#  Trainable params: 7,440 (29.06 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose                │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_1              │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_2              │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_3              │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_4              │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_5              │ (None, None, 1)        │           101 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, None)           │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,201 (24.22 KB)
#  Trainable params: 6,201 (24.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "seasonal_prior"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, None, 6)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 40)  │        240 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, None, 20)  │          0 │ dense[0][0]       │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, None, 20)  │          0 │ dense[0][0]       │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_1          │ (None, None, 20)  │          0 │ get_item_2[0][0], │
# │ (Sampling)          │                   │            │ get_item_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 240 (960.00 B)
#  Trainable params: 240 (960.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\optimizers\base_optimizer.py:731: UserWarning: Gradients do not exist for variables ['kernel'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 1.3543 - val_loss: 1.3864 - val_recon: 1.3864 - val_kl: 9.8730e-06
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2986 - val_loss: 1.3129 - val_recon: 1.3129 - val_kl: 6.6640e-06
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2839 - val_loss: 1.3166 - val_recon: 1.3166 - val_kl: 1.8408e-06
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2809 - val_loss: 1.3140 - val_recon: 1.3140 - val_kl: 4.3441e-06
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2791 - val_loss: 1.3125 - val_recon: 1.3125 - val_kl: 7.8235e-06
# Epoch 6/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2780 - val_loss: 1.3117 - val_recon: 1.3117 - val_kl: 9.1155e-06
# Epoch 7/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2770 - val_loss: 1.3107 - val_recon: 1.3107 - val_kl: 1.2326e-05
# Epoch 8/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2764 - val_loss: 1.3086 - val_recon: 1.3086 - val_kl: 1.1571e-05
# Epoch 9/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2758 - val_loss: 1.3089 - val_recon: 1.3088 - val_kl: 1.1008e-05
# Epoch 10/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2756 - val_loss: 1.3091 - val_recon: 1.3091 - val_kl: 1.2328e-05
# Epoch 11/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2752 - val_loss: 1.3075 - val_recon: 1.3075 - val_kl: 1.4680e-05
# Epoch 12/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2750 - val_loss: 1.3079 - val_recon: 1.3079 - val_kl: 1.5353e-05
# Epoch 13/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2749 - val_loss: 1.3071 - val_recon: 1.3071 - val_kl: 1.3862e-05
# Epoch 14/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2747 - val_loss: 1.3071 - val_recon: 1.3071 - val_kl: 1.0534e-05
# Epoch 15/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2745 - val_loss: 1.3068 - val_recon: 1.3068 - val_kl: 1.0484e-05
# Epoch 16/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2743 - val_loss: 1.3072 - val_recon: 1.3072 - val_kl: 1.2529e-05
# Epoch 17/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2743 - val_loss: 1.3054 - val_recon: 1.3054 - val_kl: 1.2488e-05
# Epoch 18/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2743 - val_loss: 1.3065 - val_recon: 1.3065 - val_kl: 1.3573e-05
# Epoch 19/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2742 - val_loss: 1.3060 - val_recon: 1.3059 - val_kl: 1.4196e-05
# Epoch 20/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2739 - val_loss: 1.3061 - val_recon: 1.3061 - val_kl: 1.4064e-05
# Epoch 21/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2738 - val_loss: 1.3069 - val_recon: 1.3069 - val_kl: 1.9265e-05
# Epoch 22/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2739 - val_loss: 1.3067 - val_recon: 1.3066 - val_kl: 2.2849e-05
# Epoch 23/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2738 - val_loss: 1.3061 - val_recon: 1.3061 - val_kl: 2.8788e-05
# Epoch 24/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2739 - val_loss: 1.3043 - val_recon: 1.3043 - val_kl: 2.3401e-05
# Epoch 25/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2737 - val_loss: 1.3056 - val_recon: 1.3056 - val_kl: 2.9657e-05
# Epoch 26/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2737 - val_loss: 1.3064 - val_recon: 1.3064 - val_kl: 3.0338e-05
# Epoch 27/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2735 - val_loss: 1.3049 - val_recon: 1.3049 - val_kl: 3.7665e-05
# Epoch 28/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2735 - val_loss: 1.3060 - val_recon: 1.3059 - val_kl: 4.8102e-05
# Epoch 29/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2734 - val_loss: 1.3048 - val_recon: 1.3047 - val_kl: 7.0396e-05
# Epoch 30/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2732 - val_loss: 1.3067 - val_recon: 1.3066 - val_kl: 1.0665e-04
# Epoch 31/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2735 - val_loss: 1.3054 - val_recon: 1.3052 - val_kl: 1.9372e-04
# Epoch 32/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2730 - val_loss: 1.3029 - val_recon: 1.3026 - val_kl: 3.7361e-04
# Epoch 33/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2716 - val_loss: 1.2908 - val_recon: 1.2875 - val_kl: 0.0032
# Epoch 34/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2167 - val_loss: 1.0960 - val_recon: 1.0630 - val_kl: 0.0329
# Epoch 35/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1305 - val_loss: 1.0415 - val_recon: 1.0065 - val_kl: 0.0349
# Epoch 36/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1089 - val_loss: 1.0489 - val_recon: 0.9995 - val_kl: 0.0494
# Epoch 37/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0788 - val_loss: 0.9675 - val_recon: 0.9203 - val_kl: 0.0473
# Epoch 38/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0597 - val_loss: 0.9503 - val_recon: 0.9109 - val_kl: 0.0394
# Epoch 39/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0516 - val_loss: 0.9783 - val_recon: 0.9325 - val_kl: 0.0458
# Epoch 40/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0320 - val_loss: 0.9211 - val_recon: 0.8693 - val_kl: 0.0518
# Epoch 41/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0193 - val_loss: 0.9072 - val_recon: 0.8526 - val_kl: 0.0546
# Epoch 42/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0033 - val_loss: 0.8982 - val_recon: 0.8409 - val_kl: 0.0572
# Epoch 43/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9966 - val_loss: 0.8663 - val_recon: 0.8208 - val_kl: 0.0454
# Epoch 44/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9823 - val_loss: 0.8083 - val_recon: 0.7482 - val_kl: 0.0601
# Epoch 45/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9611 - val_loss: 0.8305 - val_recon: 0.7822 - val_kl: 0.0483
# Epoch 46/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9393 - val_loss: 0.8142 - val_recon: 0.7529 - val_kl: 0.0613
# Epoch 47/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9243 - val_loss: 0.7227 - val_recon: 0.6724 - val_kl: 0.0503
# Epoch 48/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8988 - val_loss: 0.7753 - val_recon: 0.7212 - val_kl: 0.0541
# Epoch 49/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8823 - val_loss: 0.7338 - val_recon: 0.6799 - val_kl: 0.0539
# Epoch 50/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8601 - val_loss: 0.7262 - val_recon: 0.6698 - val_kl: 0.0564
# Epoch 51/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8489 - val_loss: 0.8073 - val_recon: 0.7491 - val_kl: 0.0582
# Epoch 52/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8334 - val_loss: 0.7460 - val_recon: 0.6865 - val_kl: 0.0594
# Epoch 53/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8153 - val_loss: 0.7019 - val_recon: 0.6383 - val_kl: 0.0636
# Epoch 54/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8080 - val_loss: 0.6449 - val_recon: 0.5803 - val_kl: 0.0646
# Epoch 55/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7971 - val_loss: 0.6412 - val_recon: 0.5720 - val_kl: 0.0692
# Epoch 56/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7862 - val_loss: 0.6537 - val_recon: 0.5849 - val_kl: 0.0689
# Epoch 57/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7764 - val_loss: 0.6163 - val_recon: 0.5450 - val_kl: 0.0713
# Epoch 58/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7625 - val_loss: 0.6108 - val_recon: 0.5333 - val_kl: 0.0775
# Epoch 59/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7536 - val_loss: 0.5706 - val_recon: 0.4909 - val_kl: 0.0797
# Epoch 60/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7513 - val_loss: 0.5939 - val_recon: 0.5192 - val_kl: 0.0747
# Epoch 61/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7491 - val_loss: 0.5300 - val_recon: 0.4523 - val_kl: 0.0777
# Epoch 62/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7303 - val_loss: 0.5389 - val_recon: 0.4625 - val_kl: 0.0764
# Epoch 63/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7236 - val_loss: 0.4837 - val_recon: 0.3995 - val_kl: 0.0842
# Epoch 64/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7112 - val_loss: 0.5059 - val_recon: 0.4249 - val_kl: 0.0809
# Epoch 65/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7113 - val_loss: 0.5089 - val_recon: 0.4233 - val_kl: 0.0856
# Epoch 66/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7066 - val_loss: 0.5168 - val_recon: 0.4299 - val_kl: 0.0869
# Epoch 67/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7001 - val_loss: 0.4863 - val_recon: 0.3984 - val_kl: 0.0880
# Epoch 68/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6888 - val_loss: 0.4691 - val_recon: 0.3782 - val_kl: 0.0909
# Epoch 69/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6899 - val_loss: 0.4180 - val_recon: 0.3266 - val_kl: 0.0913
# Epoch 70/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6805 - val_loss: 0.4510 - val_recon: 0.3605 - val_kl: 0.0905
# Epoch 71/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6746 - val_loss: 0.4729 - val_recon: 0.3820 - val_kl: 0.0909
# Epoch 72/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6642 - val_loss: 0.4662 - val_recon: 0.3774 - val_kl: 0.0888
# Epoch 73/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6670 - val_loss: 0.4353 - val_recon: 0.3379 - val_kl: 0.0974
# Epoch 74/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6542 - val_loss: 0.4419 - val_recon: 0.3467 - val_kl: 0.0952
# Epoch 75/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6536 - val_loss: 0.3949 - val_recon: 0.3012 - val_kl: 0.0937
# Epoch 76/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6487 - val_loss: 0.4034 - val_recon: 0.3071 - val_kl: 0.0963
# Epoch 77/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6542 - val_loss: 0.4169 - val_recon: 0.3166 - val_kl: 0.1003
# Epoch 78/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6471 - val_loss: 0.4600 - val_recon: 0.3585 - val_kl: 0.1014
# Epoch 79/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6405 - val_loss: 0.4156 - val_recon: 0.3132 - val_kl: 0.1024
# Epoch 80/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6481 - val_loss: 0.3984 - val_recon: 0.2928 - val_kl: 0.1056
# Epoch 81/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6576 - val_loss: 0.3699 - val_recon: 0.2685 - val_kl: 0.1013
# Epoch 82/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6354 - val_loss: 0.4039 - val_recon: 0.2997 - val_kl: 0.1043
# Epoch 83/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6220 - val_loss: 0.3834 - val_recon: 0.2814 - val_kl: 0.1020
# Epoch 84/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6234 - val_loss: 0.4150 - val_recon: 0.3073 - val_kl: 0.1078
# Epoch 85/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6212 - val_loss: 0.3780 - val_recon: 0.2746 - val_kl: 0.1034
# Epoch 86/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6102 - val_loss: 0.3458 - val_recon: 0.2374 - val_kl: 0.1083
# Epoch 87/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6128 - val_loss: 0.3661 - val_recon: 0.2591 - val_kl: 0.1070
# Epoch 88/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6049 - val_loss: 0.3822 - val_recon: 0.2765 - val_kl: 0.1057
# Epoch 89/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6019 - val_loss: 0.3968 - val_recon: 0.2920 - val_kl: 0.1048
# Epoch 90/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6068 - val_loss: 0.3010 - val_recon: 0.1857 - val_kl: 0.1153
# Epoch 91/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6058 - val_loss: 0.3287 - val_recon: 0.2158 - val_kl: 0.1129
# Epoch 92/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6052 - val_loss: 0.3246 - val_recon: 0.2120 - val_kl: 0.1126
# Epoch 93/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5926 - val_loss: 0.3493 - val_recon: 0.2335 - val_kl: 0.1158
# Epoch 94/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5894 - val_loss: 0.3540 - val_recon: 0.2411 - val_kl: 0.1129
# Epoch 95/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6008 - val_loss: 0.3060 - val_recon: 0.1848 - val_kl: 0.1212
# Epoch 96/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5867 - val_loss: 0.3416 - val_recon: 0.2250 - val_kl: 0.1165
# Epoch 97/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5945 - val_loss: 0.2888 - val_recon: 0.1719 - val_kl: 0.1170
# Epoch 98/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5936 - val_loss: 0.3661 - val_recon: 0.2479 - val_kl: 0.1182
# Epoch 99/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5834 - val_loss: 0.2848 - val_recon: 0.1644 - val_kl: 0.1204
# Epoch 100/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5874 - val_loss: 0.2944 - val_recon: 0.1757 - val_kl: 0.1187
# Epoch 101/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5803 - val_loss: 0.2631 - val_recon: 0.1431 - val_kl: 0.1200
# Epoch 102/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5873 - val_loss: 0.2970 - val_recon: 0.1747 - val_kl: 0.1224
# Epoch 103/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5826 - val_loss: 0.3049 - val_recon: 0.1849 - val_kl: 0.1200
# Epoch 104/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5741 - val_loss: 0.2788 - val_recon: 0.1605 - val_kl: 0.1182
# Epoch 105/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5763 - val_loss: 0.2544 - val_recon: 0.1304 - val_kl: 0.1240
# Epoch 106/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5804 - val_loss: 0.2796 - val_recon: 0.1564 - val_kl: 0.1232
# Epoch 107/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5763 - val_loss: 0.3185 - val_recon: 0.1932 - val_kl: 0.1253
# Epoch 108/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5828 - val_loss: 0.2999 - val_recon: 0.1747 - val_kl: 0.1252
# Epoch 109/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5755 - val_loss: 0.2801 - val_recon: 0.1569 - val_kl: 0.1232
# Epoch 110/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5709 - val_loss: 0.2517 - val_recon: 0.1301 - val_kl: 0.1216
# Epoch 111/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5713 - val_loss: 0.2483 - val_recon: 0.1219 - val_kl: 0.1263
# Epoch 112/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5738 - val_loss: 0.2760 - val_recon: 0.1493 - val_kl: 0.1266
# Epoch 113/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5692 - val_loss: 0.3147 - val_recon: 0.1933 - val_kl: 0.1215
# Epoch 114/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5758 - val_loss: 0.2603 - val_recon: 0.1375 - val_kl: 0.1228
# Epoch 115/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5609 - val_loss: 0.3112 - val_recon: 0.1898 - val_kl: 0.1214
# Epoch 116/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5658 - val_loss: 0.2719 - val_recon: 0.1496 - val_kl: 0.1223
# Epoch 117/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5749 - val_loss: 0.2452 - val_recon: 0.1173 - val_kl: 0.1279
# Epoch 118/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5729 - val_loss: 0.2573 - val_recon: 0.1334 - val_kl: 0.1239
# Epoch 119/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5662 - val_loss: 0.2244 - val_recon: 0.0970 - val_kl: 0.1275
# Epoch 120/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5636 - val_loss: 0.2807 - val_recon: 0.1559 - val_kl: 0.1248
# Epoch 121/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5619 - val_loss: 0.3036 - val_recon: 0.1767 - val_kl: 0.1269
# Epoch 122/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5679 - val_loss: 0.2948 - val_recon: 0.1675 - val_kl: 0.1273
# Epoch 123/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5676 - val_loss: 0.2586 - val_recon: 0.1309 - val_kl: 0.1277
# Epoch 124/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5650 - val_loss: 0.3194 - val_recon: 0.1927 - val_kl: 0.1267
# Epoch 125/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5731 - val_loss: 0.2616 - val_recon: 0.1293 - val_kl: 0.1323
# Epoch 126/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5648 - val_loss: 0.3345 - val_recon: 0.2076 - val_kl: 0.1268
# Epoch 127/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5674 - val_loss: 0.2357 - val_recon: 0.1090 - val_kl: 0.1267
# Epoch 128/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5645 - val_loss: 0.2571 - val_recon: 0.1255 - val_kl: 0.1316
# Epoch 129/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5636 - val_loss: 0.2811 - val_recon: 0.1533 - val_kl: 0.1278
# Epoch 130/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5632 - val_loss: 0.2288 - val_recon: 0.1011 - val_kl: 0.1277
# Epoch 131/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5644 - val_loss: 0.2416 - val_recon: 0.1164 - val_kl: 0.1252
# Epoch 132/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5591 - val_loss: 0.2674 - val_recon: 0.1350 - val_kl: 0.1324
# Epoch 133/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5694 - val_loss: 0.2416 - val_recon: 0.1126 - val_kl: 0.1290
# Epoch 134/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5647 - val_loss: 0.2664 - val_recon: 0.1369 - val_kl: 0.1295
# Epoch 135/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5556 - val_loss: 0.2790 - val_recon: 0.1501 - val_kl: 0.1289
# Epoch 136/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5625 - val_loss: 0.2533 - val_recon: 0.1226 - val_kl: 0.1307
# Epoch 137/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5611 - val_loss: 0.2973 - val_recon: 0.1624 - val_kl: 0.1349
# Epoch 138/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5644 - val_loss: 0.2583 - val_recon: 0.1292 - val_kl: 0.1292
# Epoch 139/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5572 - val_loss: 0.2966 - val_recon: 0.1681 - val_kl: 0.1285
# Epoch 140/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5565 - val_loss: 0.2537 - val_recon: 0.1244 - val_kl: 0.1293
# Epoch 141/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5564 - val_loss: 0.2723 - val_recon: 0.1439 - val_kl: 0.1284
# Epoch 142/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5572 - val_loss: 0.2828 - val_recon: 0.1520 - val_kl: 0.1307
# Epoch 143/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5616 - val_loss: 0.2462 - val_recon: 0.1136 - val_kl: 0.1326
# Epoch 144/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5543 - val_loss: 0.2874 - val_recon: 0.1624 - val_kl: 0.1250
# Epoch 145/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5481 - val_loss: 0.2141 - val_recon: 0.0846 - val_kl: 0.1295
# Epoch 146/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5562 - val_loss: 0.2564 - val_recon: 0.1267 - val_kl: 0.1297
# Epoch 147/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5592 - val_loss: 0.2640 - val_recon: 0.1326 - val_kl: 0.1314
# Epoch 148/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5563 - val_loss: 0.2462 - val_recon: 0.1177 - val_kl: 0.1285
# Epoch 149/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5495 - val_loss: 0.2307 - val_recon: 0.0981 - val_kl: 0.1325
# Epoch 150/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5525 - val_loss: 0.2438 - val_recon: 0.1143 - val_kl: 0.1295
# Epoch 151/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5565 - val_loss: 0.2411 - val_recon: 0.1116 - val_kl: 0.1295
# Epoch 152/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5513 - val_loss: 0.2744 - val_recon: 0.1450 - val_kl: 0.1294
# Epoch 153/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5553 - val_loss: 0.2390 - val_recon: 0.1078 - val_kl: 0.1312
# Epoch 154/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5566 - val_loss: 0.2975 - val_recon: 0.1691 - val_kl: 0.1284
# Epoch 155/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5622 - val_loss: 0.2818 - val_recon: 0.1530 - val_kl: 0.1288
# Epoch 156/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5566 - val_loss: 0.2554 - val_recon: 0.1230 - val_kl: 0.1324
# Epoch 157/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5592 - val_loss: 0.2628 - val_recon: 0.1293 - val_kl: 0.1335
# Epoch 158/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5544 - val_loss: 0.2605 - val_recon: 0.1302 - val_kl: 0.1303
# Epoch 159/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5507 - val_loss: 0.2616 - val_recon: 0.1328 - val_kl: 0.1288
# Epoch 160/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5546 - val_loss: 0.2483 - val_recon: 0.1173 - val_kl: 0.1309
# Epoch 161/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5585 - val_loss: 0.2229 - val_recon: 0.0902 - val_kl: 0.1327
# Epoch 162/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5546 - val_loss: 0.2720 - val_recon: 0.1460 - val_kl: 0.1260
# Epoch 163/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5514 - val_loss: 0.2824 - val_recon: 0.1507 - val_kl: 0.1316
# Epoch 164/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5548 - val_loss: 0.2499 - val_recon: 0.1179 - val_kl: 0.1320
# Epoch 165/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5496 - val_loss: 0.2705 - val_recon: 0.1371 - val_kl: 0.1334
# Epoch 166/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5572 - val_loss: 0.2900 - val_recon: 0.1588 - val_kl: 0.1312
# Epoch 167/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5530 - val_loss: 0.2647 - val_recon: 0.1312 - val_kl: 0.1335
# Epoch 168/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5488 - val_loss: 0.2426 - val_recon: 0.1130 - val_kl: 0.1296
# Epoch 169/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5489 - val_loss: 0.2158 - val_recon: 0.0881 - val_kl: 0.1278
# Epoch 170/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5563 - val_loss: 0.2596 - val_recon: 0.1264 - val_kl: 0.1332
# Epoch 171/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5546 - val_loss: 0.2864 - val_recon: 0.1567 - val_kl: 0.1297
# Epoch 172/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5636 - val_loss: 0.2123 - val_recon: 0.0841 - val_kl: 0.1282
# Epoch 173/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5508 - val_loss: 0.2904 - val_recon: 0.1610 - val_kl: 0.1294
# Epoch 174/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5573 - val_loss: 0.2993 - val_recon: 0.1733 - val_kl: 0.1260
# Epoch 175/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5548 - val_loss: 0.2326 - val_recon: 0.0950 - val_kl: 0.1376
# Epoch 176/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5543 - val_loss: 0.2445 - val_recon: 0.1117 - val_kl: 0.1328
# Epoch 177/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5512 - val_loss: 0.2371 - val_recon: 0.1070 - val_kl: 0.1301
# Epoch 178/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5542 - val_loss: 0.2722 - val_recon: 0.1390 - val_kl: 0.1332
# Epoch 179/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5580 - val_loss: 0.3038 - val_recon: 0.1722 - val_kl: 0.1316
# Epoch 180/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5565 - val_loss: 0.2494 - val_recon: 0.1190 - val_kl: 0.1305
# Epoch 181/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5516 - val_loss: 0.3228 - val_recon: 0.1947 - val_kl: 0.1281
# Epoch 182/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5495 - val_loss: 0.2567 - val_recon: 0.1293 - val_kl: 0.1274
# Epoch 183/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5477 - val_loss: 0.2941 - val_recon: 0.1657 - val_kl: 0.1284
# Epoch 184/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5466 - val_loss: 0.2984 - val_recon: 0.1664 - val_kl: 0.1320
# Epoch 185/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5511 - val_loss: 0.2448 - val_recon: 0.1132 - val_kl: 0.1317
# Epoch 186/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5550 - val_loss: 0.1954 - val_recon: 0.0602 - val_kl: 0.1353
# Epoch 187/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5562 - val_loss: 0.2587 - val_recon: 0.1292 - val_kl: 0.1295
# Epoch 188/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5504 - val_loss: 0.2264 - val_recon: 0.0982 - val_kl: 0.1282
# Epoch 189/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5539 - val_loss: 0.2220 - val_recon: 0.0914 - val_kl: 0.1306
# Epoch 190/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5548 - val_loss: 0.2118 - val_recon: 0.0791 - val_kl: 0.1327
# Epoch 191/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5494 - val_loss: 0.2494 - val_recon: 0.1202 - val_kl: 0.1292
# Epoch 192/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5514 - val_loss: 0.2682 - val_recon: 0.1382 - val_kl: 0.1300
# Epoch 193/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5502 - val_loss: 0.2470 - val_recon: 0.1179 - val_kl: 0.1291
# Epoch 194/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5524 - val_loss: 0.2567 - val_recon: 0.1257 - val_kl: 0.1311
# Epoch 195/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5511 - val_loss: 0.2783 - val_recon: 0.1454 - val_kl: 0.1330
# Epoch 196/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5606 - val_loss: 0.2026 - val_recon: 0.0713 - val_kl: 0.1313
# Epoch 197/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5508 - val_loss: 0.2952 - val_recon: 0.1658 - val_kl: 0.1294
# Epoch 198/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5531 - val_loss: 0.2415 - val_recon: 0.1077 - val_kl: 0.1338
# Epoch 199/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5475 - val_loss: 0.2444 - val_recon: 0.1131 - val_kl: 0.1313
# Epoch 200/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5500 - val_loss: 0.2215 - val_recon: 0.0878 - val_kl: 0.1337
# Epoch 201/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5469 - val_loss: 0.2516 - val_recon: 0.1194 - val_kl: 0.1323
# Epoch 202/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5638 - val_loss: 0.2203 - val_recon: 0.0907 - val_kl: 0.1297
# Epoch 203/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5468 - val_loss: 0.2437 - val_recon: 0.1134 - val_kl: 0.1303
# Epoch 204/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5452 - val_loss: 0.2379 - val_recon: 0.1068 - val_kl: 0.1311
# Epoch 205/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5447 - val_loss: 0.2477 - val_recon: 0.1129 - val_kl: 0.1348
# Epoch 206/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5470 - val_loss: 0.2480 - val_recon: 0.1183 - val_kl: 0.1297
# Epoch 207/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5515 - val_loss: 0.2371 - val_recon: 0.1073 - val_kl: 0.1297
# Epoch 208/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5636 - val_loss: 0.2515 - val_recon: 0.1199 - val_kl: 0.1316
# Epoch 209/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5505 - val_loss: 0.2372 - val_recon: 0.1076 - val_kl: 0.1297
# Epoch 210/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5456 - val_loss: 0.2107 - val_recon: 0.0824 - val_kl: 0.1284
# Epoch 211/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5573 - val_loss: 0.2059 - val_recon: 0.0740 - val_kl: 0.1319
# Epoch 212/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5505 - val_loss: 0.2036 - val_recon: 0.0679 - val_kl: 0.1357
# Epoch 213/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5493 - val_loss: 0.2517 - val_recon: 0.1192 - val_kl: 0.1325
# Epoch 214/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5510 - val_loss: 0.2475 - val_recon: 0.1198 - val_kl: 0.1277
# Epoch 215/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5572 - val_loss: 0.3441 - val_recon: 0.2122 - val_kl: 0.1319
# Epoch 216/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5572 - val_loss: 0.2144 - val_recon: 0.0840 - val_kl: 0.1304
# Epoch 217/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5477 - val_loss: 0.2384 - val_recon: 0.1098 - val_kl: 0.1286
# Epoch 218/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5514 - val_loss: 0.1834 - val_recon: 0.0512 - val_kl: 0.1322
# Epoch 219/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5515 - val_loss: 0.2516 - val_recon: 0.1194 - val_kl: 0.1322
# Epoch 220/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5488 - val_loss: 0.2221 - val_recon: 0.0911 - val_kl: 0.1310
# Epoch 221/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5496 - val_loss: 0.2763 - val_recon: 0.1439 - val_kl: 0.1324
# Epoch 222/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5514 - val_loss: 0.2261 - val_recon: 0.0949 - val_kl: 0.1312
# Epoch 223/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5523 - val_loss: 0.2527 - val_recon: 0.1236 - val_kl: 0.1292
# Epoch 224/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5515 - val_loss: 0.2489 - val_recon: 0.1151 - val_kl: 0.1337
# Epoch 225/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5520 - val_loss: 0.2318 - val_recon: 0.1036 - val_kl: 0.1282
# Epoch 226/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5528 - val_loss: 0.2283 - val_recon: 0.0968 - val_kl: 0.1315
# Epoch 227/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5483 - val_loss: 0.2147 - val_recon: 0.0844 - val_kl: 0.1303
# Epoch 228/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5456 - val_loss: 0.1908 - val_recon: 0.0579 - val_kl: 0.1328
# Epoch 229/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5492 - val_loss: 0.2166 - val_recon: 0.0856 - val_kl: 0.1310
# Epoch 230/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5489 - val_loss: 0.1873 - val_recon: 0.0535 - val_kl: 0.1339
# Epoch 231/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5505 - val_loss: 0.2443 - val_recon: 0.1140 - val_kl: 0.1303
# Epoch 232/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5488 - val_loss: 0.2603 - val_recon: 0.1319 - val_kl: 0.1284
# Epoch 233/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5517 - val_loss: 0.2373 - val_recon: 0.1071 - val_kl: 0.1301
# Epoch 234/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5475 - val_loss: 0.3158 - val_recon: 0.1849 - val_kl: 0.1309
# Epoch 235/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5552 - val_loss: 0.2137 - val_recon: 0.0827 - val_kl: 0.1310
# Epoch 236/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5534 - val_loss: 0.2240 - val_recon: 0.0887 - val_kl: 0.1353
# Epoch 237/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5523 - val_loss: 0.2624 - val_recon: 0.1322 - val_kl: 0.1302
# Epoch 238/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5433 - val_loss: 0.2641 - val_recon: 0.1357 - val_kl: 0.1284
# Epoch 239/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5446 - val_loss: 0.2706 - val_recon: 0.1382 - val_kl: 0.1325
# Epoch 240/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5485 - val_loss: 0.2518 - val_recon: 0.1209 - val_kl: 0.1309
# Epoch 241/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5535 - val_loss: 0.2510 - val_recon: 0.1159 - val_kl: 0.1350
# Epoch 242/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5478 - val_loss: 0.2569 - val_recon: 0.1303 - val_kl: 0.1266
# Epoch 243/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5476 - val_loss: 0.2281 - val_recon: 0.0961 - val_kl: 0.1319
# Epoch 244/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5503 - val_loss: 0.2786 - val_recon: 0.1497 - val_kl: 0.1288
# Epoch 245/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5444 - val_loss: 0.2532 - val_recon: 0.1237 - val_kl: 0.1295
# Epoch 246/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5500 - val_loss: 0.2398 - val_recon: 0.1092 - val_kl: 0.1306
# Epoch 247/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5564 - val_loss: 0.2387 - val_recon: 0.1073 - val_kl: 0.1314
# Epoch 248/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5587 - val_loss: 0.2397 - val_recon: 0.1065 - val_kl: 0.1332
# Epoch 249/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5491 - val_loss: 0.2795 - val_recon: 0.1471 - val_kl: 0.1324
# Epoch 250/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5480 - val_loss: 0.2364 - val_recon: 0.1013 - val_kl: 0.1352
# Epoch 251/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5510 - val_loss: 0.2381 - val_recon: 0.1052 - val_kl: 0.1329
# Epoch 252/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5516 - val_loss: 0.2621 - val_recon: 0.1332 - val_kl: 0.1289
# Epoch 253/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5510 - val_loss: 0.2700 - val_recon: 0.1386 - val_kl: 0.1314
# Epoch 254/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5470 - val_loss: 0.2526 - val_recon: 0.1210 - val_kl: 0.1316
# Epoch 255/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5574 - val_loss: 0.2418 - val_recon: 0.1098 - val_kl: 0.1321
# Epoch 256/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5568 - val_loss: 0.2265 - val_recon: 0.0948 - val_kl: 0.1317
# Epoch 257/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5465 - val_loss: 0.2392 - val_recon: 0.1080 - val_kl: 0.1312
# Epoch 258/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5435 - val_loss: 0.1975 - val_recon: 0.0658 - val_kl: 0.1317
# Epoch 259/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5452 - val_loss: 0.2859 - val_recon: 0.1561 - val_kl: 0.1298
# Epoch 260/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5526 - val_loss: 0.2570 - val_recon: 0.1249 - val_kl: 0.1321
# Epoch 261/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5447 - val_loss: 0.2960 - val_recon: 0.1639 - val_kl: 0.1321
# Epoch 262/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5490 - val_loss: 0.3014 - val_recon: 0.1706 - val_kl: 0.1308
# Epoch 263/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5607 - val_loss: 0.2755 - val_recon: 0.1484 - val_kl: 0.1271
# Epoch 264/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5609 - val_loss: 0.2695 - val_recon: 0.1386 - val_kl: 0.1310
# Epoch 265/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5585 - val_loss: 0.3434 - val_recon: 0.2104 - val_kl: 0.1330
# Epoch 266/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5548 - val_loss: 0.2669 - val_recon: 0.1375 - val_kl: 0.1294
# Epoch 267/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5442 - val_loss: 0.2017 - val_recon: 0.0675 - val_kl: 0.1343
# Epoch 268/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5444 - val_loss: 0.2585 - val_recon: 0.1284 - val_kl: 0.1301
# Epoch 269/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5485 - val_loss: 0.2233 - val_recon: 0.0930 - val_kl: 0.1303
# Epoch 270/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5455 - val_loss: 0.2437 - val_recon: 0.1151 - val_kl: 0.1286
# Epoch 271/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5498 - val_loss: 0.2789 - val_recon: 0.1492 - val_kl: 0.1297
# Epoch 272/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5548 - val_loss: 0.3027 - val_recon: 0.1729 - val_kl: 0.1298
# Epoch 273/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5438 - val_loss: 0.2808 - val_recon: 0.1502 - val_kl: 0.1306
# Epoch 274/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5532 - val_loss: 0.2347 - val_recon: 0.1043 - val_kl: 0.1304
# Epoch 275/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5473 - val_loss: 0.2700 - val_recon: 0.1401 - val_kl: 0.1298
# Epoch 276/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5526 - val_loss: 0.2326 - val_recon: 0.0994 - val_kl: 0.1332
# Epoch 277/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5603 - val_loss: 0.3075 - val_recon: 0.1749 - val_kl: 0.1326
# Epoch 278/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5527 - val_loss: 0.2107 - val_recon: 0.0789 - val_kl: 0.1318
# Epoch 279/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5505 - val_loss: 0.2827 - val_recon: 0.1524 - val_kl: 0.1303
# Epoch 280/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5507 - val_loss: 0.2611 - val_recon: 0.1306 - val_kl: 0.1306
# Epoch 281/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5473 - val_loss: 0.2255 - val_recon: 0.0960 - val_kl: 0.1294
# Epoch 282/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5444 - val_loss: 0.3042 - val_recon: 0.1744 - val_kl: 0.1298
# Epoch 283/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5549 - val_loss: 0.2318 - val_recon: 0.1018 - val_kl: 0.1300
# Epoch 284/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5409 - val_loss: 0.2412 - val_recon: 0.1143 - val_kl: 0.1270
# Epoch 285/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5507 - val_loss: 0.2663 - val_recon: 0.1366 - val_kl: 0.1297
# Epoch 286/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5539 - val_loss: 0.2374 - val_recon: 0.1079 - val_kl: 0.1294
# Epoch 287/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5494 - val_loss: 0.2434 - val_recon: 0.1122 - val_kl: 0.1312
# Epoch 288/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5455 - val_loss: 0.2355 - val_recon: 0.1054 - val_kl: 0.1301
# Epoch 289/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5445 - val_loss: 0.2263 - val_recon: 0.0939 - val_kl: 0.1324
# Epoch 290/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5547 - val_loss: 0.2435 - val_recon: 0.1143 - val_kl: 0.1292
# Epoch 291/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5521 - val_loss: 0.2501 - val_recon: 0.1183 - val_kl: 0.1318
# Epoch 292/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5482 - val_loss: 0.2131 - val_recon: 0.0836 - val_kl: 0.1295
# Epoch 293/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5443 - val_loss: 0.2117 - val_recon: 0.0822 - val_kl: 0.1295
# Epoch 294/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5549 - val_loss: 0.2147 - val_recon: 0.0848 - val_kl: 0.1299
# Epoch 295/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5473 - val_loss: 0.2795 - val_recon: 0.1501 - val_kl: 0.1294
# Epoch 296/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5565 - val_loss: 0.2867 - val_recon: 0.1561 - val_kl: 0.1306
# Epoch 297/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5516 - val_loss: 0.2625 - val_recon: 0.1332 - val_kl: 0.1293
# Epoch 298/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5498 - val_loss: 0.2136 - val_recon: 0.0824 - val_kl: 0.1311
# Epoch 299/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5480 - val_loss: 0.2524 - val_recon: 0.1230 - val_kl: 0.1295
# Epoch 300/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5495 - val_loss: 0.2473 - val_recon: 0.1160 - val_kl: 0.1312
# Epoch 301/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5380 - val_loss: 0.3059 - val_recon: 0.1815 - val_kl: 0.1245
# Epoch 302/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5498 - val_loss: 0.2373 - val_recon: 0.1049 - val_kl: 0.1323
# Epoch 303/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5463 - val_loss: 0.2518 - val_recon: 0.1198 - val_kl: 0.1320
# Epoch 304/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5484 - val_loss: 0.1936 - val_recon: 0.0621 - val_kl: 0.1316
# Epoch 305/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5483 - val_loss: 0.2485 - val_recon: 0.1184 - val_kl: 0.1301
# Epoch 306/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5460 - val_loss: 0.2522 - val_recon: 0.1215 - val_kl: 0.1307
# Epoch 307/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5497 - val_loss: 0.2703 - val_recon: 0.1399 - val_kl: 0.1303
# Epoch 308/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5492 - val_loss: 0.2388 - val_recon: 0.1070 - val_kl: 0.1318
# Epoch 309/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5474 - val_loss: 0.2473 - val_recon: 0.1159 - val_kl: 0.1314
# Epoch 310/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5436 - val_loss: 0.2446 - val_recon: 0.1141 - val_kl: 0.1304
# Epoch 311/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5493 - val_loss: 0.2557 - val_recon: 0.1228 - val_kl: 0.1329
# Epoch 312/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5501 - val_loss: 0.2093 - val_recon: 0.0752 - val_kl: 0.1342
# Epoch 313/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5456 - val_loss: 0.2468 - val_recon: 0.1155 - val_kl: 0.1313
# Epoch 314/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5511 - val_loss: 0.2272 - val_recon: 0.0952 - val_kl: 0.1320
# Epoch 315/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5457 - val_loss: 0.2636 - val_recon: 0.1287 - val_kl: 0.1349
# Epoch 316/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5488 - val_loss: 0.2378 - val_recon: 0.1078 - val_kl: 0.1300
# Epoch 317/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5564 - val_loss: 0.2206 - val_recon: 0.0843 - val_kl: 0.1363
# Epoch 318/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5469 - val_loss: 0.2830 - val_recon: 0.1483 - val_kl: 0.1347
# Epoch 319/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5491 - val_loss: 0.2370 - val_recon: 0.1061 - val_kl: 0.1309
# Epoch 320/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5484 - val_loss: 0.2527 - val_recon: 0.1223 - val_kl: 0.1303
# Epoch 321/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5527 - val_loss: 0.3937 - val_recon: 0.2654 - val_kl: 0.1283
# Epoch 322/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5633 - val_loss: 0.2610 - val_recon: 0.1313 - val_kl: 0.1298
# Epoch 323/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5440 - val_loss: 0.2789 - val_recon: 0.1519 - val_kl: 0.1270
# Epoch 324/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5472 - val_loss: 0.2854 - val_recon: 0.1533 - val_kl: 0.1321
# Epoch 325/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5479 - val_loss: 0.2410 - val_recon: 0.1065 - val_kl: 0.1345
# Epoch 326/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5465 - val_loss: 0.2456 - val_recon: 0.1126 - val_kl: 0.1330
# Epoch 327/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5488 - val_loss: 0.2093 - val_recon: 0.0742 - val_kl: 0.1350
# Epoch 328/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5511 - val_loss: 0.2353 - val_recon: 0.1027 - val_kl: 0.1325
# Epoch 329/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5450 - val_loss: 0.2604 - val_recon: 0.1281 - val_kl: 0.1323
# Epoch 330/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5439 - val_loss: 0.2680 - val_recon: 0.1373 - val_kl: 0.1307
# Epoch 331/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5489 - val_loss: 0.2833 - val_recon: 0.1514 - val_kl: 0.1320
# Epoch 332/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5496 - val_loss: 0.2672 - val_recon: 0.1401 - val_kl: 0.1270
# Epoch 333/500
# ...
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5543 - val_loss: 0.2635 - val_recon: 0.1280 - val_kl: 0.1355
# Epoch 375/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5464 - val_loss: 0.1998 - val_recon: 0.0651 - val_kl: 0.1347
# Epoch 376/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5414 - val_loss: 0.2426 - val_recon: 0.1137 - val_kl: 0.1289
# Epoch 377/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5449 - val_loss: 0.2285 - val_recon: 0.1001 - val_kl: 0.1283
# Epoch 378/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5487 - val_loss: 0.2529 - val_recon: 0.1192 - val_kl: 0.1337
# Epoch 379/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5442 - val_loss: 0.2165 - val_recon: 0.0890 - val_kl: 0.1275
# Epoch 380/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5460 - val_loss: 0.2493 - val_recon: 0.1149 - val_kl: 0.1344
# Epoch 381/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5468 - val_loss: 0.2750 - val_recon: 0.1421 - val_kl: 0.1330
# Epoch 382/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5445 - val_loss: 0.2807 - val_recon: 0.1495 - val_kl: 0.1312
# Epoch 383/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5434 - val_loss: 0.2463 - val_recon: 0.1119 - val_kl: 0.1343
# Epoch 384/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5467 - val_loss: 0.2408 - val_recon: 0.1076 - val_kl: 0.1331
# Epoch 385/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5472 - val_loss: 0.2338 - val_recon: 0.1023 - val_kl: 0.1315
# Epoch 386/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5445 - val_loss: 0.2223 - val_recon: 0.0903 - val_kl: 0.1319
# Epoch 387/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5435 - val_loss: 0.2105 - val_recon: 0.0780 - val_kl: 0.1325
# Epoch 388/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5487 - val_loss: 0.2502 - val_recon: 0.1209 - val_kl: 0.1293
# Epoch 389/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5465 - val_loss: 0.2615 - val_recon: 0.1308 - val_kl: 0.1307
# Epoch 390/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5469 - val_loss: 0.2321 - val_recon: 0.1003 - val_kl: 0.1318
# Epoch 391/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5377 - val_loss: 0.2307 - val_recon: 0.1006 - val_kl: 0.1300
# Epoch 392/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5520 - val_loss: 0.2961 - val_recon: 0.1642 - val_kl: 0.1319
# Epoch 393/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5475 - val_loss: 0.2098 - val_recon: 0.0768 - val_kl: 0.1330
# Epoch 394/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5444 - val_loss: 0.2293 - val_recon: 0.0964 - val_kl: 0.1329
# Epoch 395/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5442 - val_loss: 0.2295 - val_recon: 0.0962 - val_kl: 0.1334
# Epoch 396/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5509 - val_loss: 0.2287 - val_recon: 0.1002 - val_kl: 0.1285
# Epoch 397/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5434 - val_loss: 0.2251 - val_recon: 0.0956 - val_kl: 0.1295
# Epoch 398/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5446 - val_loss: 0.2376 - val_recon: 0.1101 - val_kl: 0.1275
# Epoch 399/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5477 - val_loss: 0.2598 - val_recon: 0.1281 - val_kl: 0.1317
# Epoch 400/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5447 - val_loss: 0.2251 - val_recon: 0.0954 - val_kl: 0.1297
# Epoch 401/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5513 - val_loss: 0.2699 - val_recon: 0.1398 - val_kl: 0.1302
# Epoch 402/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5439 - val_loss: 0.2328 - val_recon: 0.1030 - val_kl: 0.1298
# Epoch 403/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5458 - val_loss: 0.1828 - val_recon: 0.0506 - val_kl: 0.1322
# Epoch 404/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5475 - val_loss: 0.2232 - val_recon: 0.0913 - val_kl: 0.1320
# Epoch 405/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5430 - val_loss: 0.2051 - val_recon: 0.0731 - val_kl: 0.1320
# Epoch 406/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5501 - val_loss: 0.2383 - val_recon: 0.1064 - val_kl: 0.1320
# Epoch 407/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5498 - val_loss: 0.2375 - val_recon: 0.1043 - val_kl: 0.1332
# Epoch 408/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5548 - val_loss: 0.2189 - val_recon: 0.0854 - val_kl: 0.1336
# Epoch 409/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5414 - val_loss: 0.3124 - val_recon: 0.1837 - val_kl: 0.1287
# Epoch 410/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5442 - val_loss: 0.2889 - val_recon: 0.1571 - val_kl: 0.1318
# Epoch 411/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5476 - val_loss: 0.2144 - val_recon: 0.0835 - val_kl: 0.1309
# Epoch 412/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5455 - val_loss: 0.2573 - val_recon: 0.1265 - val_kl: 0.1309
# Epoch 413/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5432 - val_loss: 0.2168 - val_recon: 0.0846 - val_kl: 0.1322
# Epoch 414/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5470 - val_loss: 0.2513 - val_recon: 0.1180 - val_kl: 0.1333
# Epoch 415/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5447 - val_loss: 0.2729 - val_recon: 0.1414 - val_kl: 0.1315
# Epoch 416/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5551 - val_loss: 0.2650 - val_recon: 0.1317 - val_kl: 0.1333
# Epoch 417/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5464 - val_loss: 0.2462 - val_recon: 0.1177 - val_kl: 0.1284
# Epoch 418/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5486 - val_loss: 0.2306 - val_recon: 0.0969 - val_kl: 0.1337
# Epoch 419/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5436 - val_loss: 0.2265 - val_recon: 0.0937 - val_kl: 0.1327
# Epoch 420/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5434 - val_loss: 0.3173 - val_recon: 0.1907 - val_kl: 0.1266
# Epoch 421/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5471 - val_loss: 0.2700 - val_recon: 0.1429 - val_kl: 0.1271
# Epoch 422/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5510 - val_loss: 0.2635 - val_recon: 0.1310 - val_kl: 0.1325
# Epoch 423/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5399 - val_loss: 0.2377 - val_recon: 0.1096 - val_kl: 0.1280
# Epoch 424/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5497 - val_loss: 0.2286 - val_recon: 0.0996 - val_kl: 0.1290
# Epoch 425/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5423 - val_loss: 0.2145 - val_recon: 0.0834 - val_kl: 0.1311
# Epoch 426/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5484 - val_loss: 0.2554 - val_recon: 0.1253 - val_kl: 0.1301
# Epoch 427/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5482 - val_loss: 0.2289 - val_recon: 0.1002 - val_kl: 0.1288
# Epoch 428/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5445 - val_loss: 0.2776 - val_recon: 0.1493 - val_kl: 0.1283
# Epoch 429/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5438 - val_loss: 0.2855 - val_recon: 0.1578 - val_kl: 0.1277
# Epoch 430/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5447 - val_loss: 0.2395 - val_recon: 0.1066 - val_kl: 0.1329
# Epoch 431/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5432 - val_loss: 0.2379 - val_recon: 0.1038 - val_kl: 0.1340
# Epoch 432/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5451 - val_loss: 0.2261 - val_recon: 0.0954 - val_kl: 0.1307
# Epoch 433/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5391 - val_loss: 0.2696 - val_recon: 0.1411 - val_kl: 0.1285
# Epoch 434/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5431 - val_loss: 0.2539 - val_recon: 0.1262 - val_kl: 0.1277
# Epoch 435/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5450 - val_loss: 0.2633 - val_recon: 0.1310 - val_kl: 0.1323
# Epoch 436/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5471 - val_loss: 0.2439 - val_recon: 0.1159 - val_kl: 0.1280
# Epoch 437/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5442 - val_loss: 0.2137 - val_recon: 0.0819 - val_kl: 0.1318
# Epoch 438/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5460 - val_loss: 0.2727 - val_recon: 0.1411 - val_kl: 0.1316
# Epoch 439/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5478 - val_loss: 0.2408 - val_recon: 0.1084 - val_kl: 0.1324
# Epoch 440/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5453 - val_loss: 0.2390 - val_recon: 0.1079 - val_kl: 0.1311
# Epoch 441/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5499 - val_loss: 0.2320 - val_recon: 0.1005 - val_kl: 0.1315
# Epoch 442/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5414 - val_loss: 0.2058 - val_recon: 0.0758 - val_kl: 0.1300
# Epoch 443/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5468 - val_loss: 0.2488 - val_recon: 0.1153 - val_kl: 0.1335
# Epoch 444/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5469 - val_loss: 0.2658 - val_recon: 0.1328 - val_kl: 0.1330
# Epoch 445/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5479 - val_loss: 0.2131 - val_recon: 0.0805 - val_kl: 0.1325
# Epoch 446/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5453 - val_loss: 0.2475 - val_recon: 0.1187 - val_kl: 0.1288
# Epoch 447/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5600 - val_loss: 0.2679 - val_recon: 0.1408 - val_kl: 0.1271
# Epoch 448/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5461 - val_loss: 0.2583 - val_recon: 0.1290 - val_kl: 0.1292
# Epoch 449/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5504 - val_loss: 0.2641 - val_recon: 0.1333 - val_kl: 0.1308
# Epoch 450/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5500 - val_loss: 0.2613 - val_recon: 0.1286 - val_kl: 0.1327
# Epoch 451/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5423 - val_loss: 0.2564 - val_recon: 0.1250 - val_kl: 0.1314
# Epoch 452/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5416 - val_loss: 0.2717 - val_recon: 0.1415 - val_kl: 0.1302
# Epoch 453/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5488 - val_loss: 0.2549 - val_recon: 0.1255 - val_kl: 0.1295
# Epoch 454/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5451 - val_loss: 0.2439 - val_recon: 0.1132 - val_kl: 0.1307
# Epoch 455/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5431 - val_loss: 0.2583 - val_recon: 0.1290 - val_kl: 0.1292
# Epoch 456/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5527 - val_loss: 0.2283 - val_recon: 0.0969 - val_kl: 0.1314
# Epoch 457/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5408 - val_loss: 0.2345 - val_recon: 0.1031 - val_kl: 0.1314
# Epoch 458/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5404 - val_loss: 0.2873 - val_recon: 0.1564 - val_kl: 0.1309
# Epoch 459/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5439 - val_loss: 0.2348 - val_recon: 0.1028 - val_kl: 0.1320
# Epoch 460/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5435 - val_loss: 0.2243 - val_recon: 0.0960 - val_kl: 0.1284
# Epoch 461/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5430 - val_loss: 0.2217 - val_recon: 0.0902 - val_kl: 0.1315
# Epoch 462/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5445 - val_loss: 0.2183 - val_recon: 0.0853 - val_kl: 0.1330
# Epoch 463/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5403 - val_loss: 0.2691 - val_recon: 0.1380 - val_kl: 0.1311
# Epoch 464/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5418 - val_loss: 0.2286 - val_recon: 0.0991 - val_kl: 0.1295
# Epoch 465/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5446 - val_loss: 0.2386 - val_recon: 0.1065 - val_kl: 0.1321
# Epoch 466/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5448 - val_loss: 0.2658 - val_recon: 0.1339 - val_kl: 0.1320
# Epoch 467/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5468 - val_loss: 0.2283 - val_recon: 0.0960 - val_kl: 0.1323
# Epoch 468/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5410 - val_loss: 0.2302 - val_recon: 0.1012 - val_kl: 0.1290
# Epoch 469/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5422 - val_loss: 0.2486 - val_recon: 0.1182 - val_kl: 0.1304
# Epoch 470/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5532 - val_loss: 0.2274 - val_recon: 0.0934 - val_kl: 0.1340
# Epoch 471/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5499 - val_loss: 0.2177 - val_recon: 0.0899 - val_kl: 0.1278
# Epoch 472/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5414 - val_loss: 0.2971 - val_recon: 0.1681 - val_kl: 0.1290
# Epoch 473/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5418 - val_loss: 0.2286 - val_recon: 0.1015 - val_kl: 0.1271
# Epoch 474/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5456 - val_loss: 0.2318 - val_recon: 0.1005 - val_kl: 0.1313
# Epoch 475/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5437 - val_loss: 0.2479 - val_recon: 0.1152 - val_kl: 0.1327
# Epoch 476/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5438 - val_loss: 0.2590 - val_recon: 0.1267 - val_kl: 0.1324
# Epoch 477/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5451 - val_loss: 0.2311 - val_recon: 0.0975 - val_kl: 0.1336
# Epoch 478/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5414 - val_loss: 0.2898 - val_recon: 0.1585 - val_kl: 0.1313
# Epoch 479/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5462 - val_loss: 0.2882 - val_recon: 0.1580 - val_kl: 0.1302
# Epoch 480/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5485 - val_loss: 0.2178 - val_recon: 0.0851 - val_kl: 0.1327
# Epoch 481/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5394 - val_loss: 0.3045 - val_recon: 0.1733 - val_kl: 0.1312
# Epoch 482/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5413 - val_loss: 0.2803 - val_recon: 0.1522 - val_kl: 0.1281
# Epoch 483/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5459 - val_loss: 0.2142 - val_recon: 0.0829 - val_kl: 0.1313
# Epoch 484/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5464 - val_loss: 0.2105 - val_recon: 0.0816 - val_kl: 0.1289
# Epoch 485/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5421 - val_loss: 0.2386 - val_recon: 0.1105 - val_kl: 0.1281
# Epoch 486/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5479 - val_loss: 0.2578 - val_recon: 0.1281 - val_kl: 0.1297
# Epoch 487/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5445 - val_loss: 0.2047 - val_recon: 0.0726 - val_kl: 0.1321
# Epoch 488/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5415 - val_loss: 0.3152 - val_recon: 0.1864 - val_kl: 0.1288
# Epoch 489/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5404 - val_loss: 0.2187 - val_recon: 0.0890 - val_kl: 0.1297
# Epoch 490/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5472 - val_loss: 0.2261 - val_recon: 0.0946 - val_kl: 0.1316
# Epoch 491/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5455 - val_loss: 0.2135 - val_recon: 0.0823 - val_kl: 0.1312
# Epoch 492/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5430 - val_loss: 0.2352 - val_recon: 0.0995 - val_kl: 0.1358
# Epoch 493/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5448 - val_loss: 0.2196 - val_recon: 0.0903 - val_kl: 0.1293
# Epoch 494/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5461 - val_loss: 0.2526 - val_recon: 0.1224 - val_kl: 0.1302
# Epoch 495/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5441 - val_loss: 0.1930 - val_recon: 0.0622 - val_kl: 0.1308
# Epoch 496/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5501 - val_loss: 0.2205 - val_recon: 0.0887 - val_kl: 0.1318
# Epoch 497/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5441 - val_loss: 0.2513 - val_recon: 0.1186 - val_kl: 0.1327
# Epoch 498/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5452 - val_loss: 0.2403 - val_recon: 0.1093 - val_kl: 0.1310
# Epoch 499/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5450 - val_loss: 0.2206 - val_recon: 0.0881 - val_kl: 0.1324
# Epoch 500/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5523 - val_loss: 0.2792 - val_recon: 0.1463 - val_kl: 0.1330
# noise emission sigma:  0.2648758
# Reconstruction loss:  0.083305255
# KL loss:              3.5737007
# Total loss:           3.657006

# %% [markdown]
# ## Generating new data

# %%
# %matplotlib notebook


'''
data.index = pd.to_datetime(data.index, format='mixed')

starting_day = np.array([d.timetuple().tm_yday for d in data.index])[:, np.newaxis]
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)
'''

os.makedirs('data/processed', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
seasonal_prior = build_seasonal_prior()
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
vae.compile()

starting_day = np.array([d.timetuple().tm_yday for d in data.index])[:, np.newaxis]
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)

gen_dataset = data.values
gen_dataset_seasonal = seasonal_data

# convert to tensors
gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32)
gen_dataset_seasonal_tensor = tf.convert_to_tensor(gen_dataset_seasonal, dtype=tf.float32)

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)

# set figure size
plt.figure(figsize=(15, 5))
# boxplot of encoded_mean
plt.subplot(1, 2, 1)
plt.boxplot(encoded_mean.numpy().reshape(-1, latent_filter))
plt.title('Encoded Mean')

# boxplot of encoded_log_var
plt.subplot(1, 2, 2)
plt.boxplot(encoded_log_var.numpy().reshape(-1, latent_filter))
plt.title('Encoded Log Variance')

plt.savefig("images/encoded_log_variance.png", dpi=300)

start_date = '1970-01-01 00:00:00'
end_date = '2020-12-31 16:00:00' 
dt = pd.date_range(start=start_date, end=end_date, freq='h')

gen_seasonal_inputs = fourier((dt.dayofyear[::LATENT_SIZE])/365)[np.newaxis]
_, _, z_gen = seasonal_prior(gen_seasonal_inputs)

gen_mean = decoder(z_gen).numpy()
noise = np.random.normal(size=gen_mean.shape)*np.exp(0.5*vae.noise_log_var[0].numpy())
gen = gen_mean + noise
n_latents = int(np.ceil(len(dt) / LATENT_SIZE))
z_gen = np.random.normal(size=(1, n_latents, latent_filter)).astype(np.float32)

gen_mean = decoder(z_gen).numpy()

data_params = pd.read_csv('data/data_params.csv', index_col=0)
offset = data_params.loc['offset', 'values']
scale = data_params.loc['scale', 'values']

gen_series = pd.Series(gen[0, :len(dt)]*scale + offset, index=dt)
gen_series = gen_series.rename('temperature')
gen_series = gen_series.to_frame()
gen_series.index.name = 'time'

# Add back seasonal cycle
df_obs = pd.read_csv('data/processed/observed_time_series.csv', index_col=0, parse_dates=True)
df_obs['weekofyear'] = df_obs.index.isocalendar().week
weekly_climatology = df_obs.groupby('weekofyear')['Observed'].mean()

# Map each hour in generated time series to its weekly mean
week_numbers = gen_series.index.isocalendar().week
seasonal_cycle = np.array([weekly_climatology[w] for w in week_numbers])
gen_series['temperature'] += seasonal_cycle

gen_series.to_csv('data/processed/generated.csv')

print(f"Succesfully generated time series of length: {len(gen_series.iloc[:,0])}")

gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')
plt.savefig('images/generated_monthly_avg.png', dpi=300)
# Out:
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# <div id='551eefa0-af7d-452b-9cba-60290c0e0357'></div>
# Succesfully generated time series of length: 447065
# C:\Users\lokes\AppData\Local\Temp\ipykernel_27488\3180306354.py:105: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')

# %% [markdown]
# ### Latent Space Analysis

# %%
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
seasonal_prior = build_seasonal_prior()
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
# optimizer = Adam(learning_rate=learning_rate)
vae.compile()

starting_day = np.array([d.timetuple().tm_yday for d in data.index])[:, np.newaxis]
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)
#------------------------------------------------------------------------------
gen_dataset = data.values
gen_dataset_seasonal = seasonal_data

gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32) # convert to tensors
gen_dataset_seasonal_tensor = tf.convert_to_tensor(gen_dataset_seasonal, dtype=tf.float32)
#------------------------------------------------------------------------------

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)
# Out:
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Latent Space Plotting Stuff

# %%
# %matplotlib notebook

# Setup
os.makedirs('images', exist_ok=True)

# Load data
latent_vectors = np.load("data/processed/latent_vectors.npy")
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

if latent_vectors.shape[0] != data.shape[0]:
    print(f"Mismatch: {latent_vectors.shape[0]} latent vectors vs {data.shape[0]} rows in CSV. Trimming data.")
    data = data.iloc[:latent_vectors.shape[0]]

# Colour labels
mean_temps = data.mean(axis=1)
day_of_year_frac = data.index.dayofyear / 365.0
hour_of_day_frac = data.index.hour / 24.0

# Flatten latent vectors
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)

# Reduce dimensions
print("First performing a PCA")
pca = PCA(n_components=2)
pca_latents = pca.fit_transform(flat_latents)
print("PCA done")

print("Now performing t-SNE")
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_latents = tsne.fit_transform(flat_latents)
print("t-SNE done")

print("Now performing UMAP")
umap_model = umap.UMAP(n_components=2, random_state=42)
umap_latents = umap_model.fit_transform(flat_latents)
print("UMAP done")

# Helper for plotting
colorings = {
    "Mean Temp": mean_temps,
    "Day of Year (Fraction)": day_of_year_frac,
    "Hour of Day (Fraction)": hour_of_day_frac
}

reduced_spaces = {
    "Raw": flat_latents,
    "PCA": pca_latents,
    "t-SNE": tsne_latents,
    "UMAP": umap_latents
}

# Plot
fig, axs = plt.subplots(4, 3, figsize=(18, 20))

# Define colormaps for each coloring
cmap_dict = {
    "Mean Temp": "coolwarm",
    "Day of Year (Fraction)": "viridis",
    "Hour of Day (Fraction)": "plasma"
}

for i, (method_name, embedding) in enumerate(reduced_spaces.items()):
    for j, (label_name, label_values) in enumerate(colorings.items()):
        print(f"Plotting {method_name} coloured by {label_name}")
        ax = axs[i, j]
        cmap = cmap_dict.get(label_name, "viridis")
        scatter = ax.scatter(embedding[:, 0], embedding[:, 1], c=label_values, cmap=cmap, s=8, alpha=0.7)
        ax.set_title(f"{method_name} - Coloured by {label_name}")
        ax.set_xticks([])
        ax.set_yticks([])
        fig.colorbar(scatter, ax=ax, fraction=0.03, pad=0.01)

plt.tight_layout()
plt.savefig("images/latent_space_analysis.png", dpi=500)
plt.close()
print("Saved mega plot to images/latent_space_analysis.png")
# Out:
# First performing a PCA
# PCA done
# Now performing t-SNE
# t-SNE done
# Now performing UMAP
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP done
# <div id='c85491b8-83b8-407f-b0ab-fe834ae07d7a'></div>
# Plotting Raw coloured by Mean Temp
# Plotting Raw coloured by Day of Year (Fraction)
# Plotting Raw coloured by Hour of Day (Fraction)
# Plotting PCA coloured by Mean Temp
# Plotting PCA coloured by Day of Year (Fraction)
# Plotting PCA coloured by Hour of Day (Fraction)
# Plotting t-SNE coloured by Mean Temp
# Plotting t-SNE coloured by Day of Year (Fraction)
# Plotting t-SNE coloured by Hour of Day (Fraction)
# Plotting UMAP coloured by Mean Temp
# Plotting UMAP coloured by Day of Year (Fraction)
# Plotting UMAP coloured by Hour of Day (Fraction)
# Saved mega plot to images/latent_space_analysis.png

# %% [markdown]
# ## Wrap up

# %%
# Define paths
folders_to_move = [
    'images',
    'model',
    os.path.join('data', 'processed')
]

files_to_move = [
    os.path.join('data', 'data_params.csv'),
    os.path.join('data', 'train_summary.csv')
]

results_directory = 'results/training_run_' + prior_dist_type + '_prior_' + str(False) + '_phase_shift_' + str(epochs) + '_epochs'

# Create the results directory if it doesn't exist
os.makedirs(results_directory, exist_ok=True)

# Move folders
for folder in folders_to_move:
    if os.path.isdir(folder):
        dest_folder = os.path.join(results_directory, os.path.basename(folder))
        shutil.move(folder, dest_folder)
        print(f"Moved folder '{folder}' to '{dest_folder}'")
    else:
        print(f"Folder not found: {folder}")

# Move files
for file in files_to_move:
    if os.path.isfile(file):
        dest_file = os.path.join(results_directory, os.path.basename(file))
        shutil.move(file, dest_file)
        print(f"Moved file '{file}' to '{dest_file}'")
    else:
        print(f"File not found: {file}")

# Delete __pycache__ folder if it exists
pycache_folder = '__pycache__'
if os.path.isdir(pycache_folder):
    shutil.rmtree(pycache_folder)
    print(f"Deleted folder '{pycache_folder}'")
# Out:
# Moved folder 'images' to 'results/training_run_Normal_prior_False_phase_shift_500_epochs\images'
# Moved folder 'model' to 'results/training_run_Normal_prior_False_phase_shift_500_epochs\model'
# Moved folder 'data\processed' to 'results/training_run_Normal_prior_False_phase_shift_500_epochs\processed'
# Moved file 'data\data_params.csv' to 'results/training_run_Normal_prior_False_phase_shift_500_epochs\data_params.csv'
# Moved file 'data\train_summary.csv' to 'results/training_run_Normal_prior_False_phase_shift_500_epochs\train_summary.csv'
# Deleted folder '__pycache__'
