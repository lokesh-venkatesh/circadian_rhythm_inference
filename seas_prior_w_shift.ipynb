# %% [markdown]
# # Training Run - Seasonal Prior & phase shifted inputs

# %% [markdown]
# #### Importing Libraries:

# %%
import subprocess
import os
import sys
import argparse
import shutil
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap.umap_ as umap
import os

from utils import *

# %% [markdown]
# ### Config

# %%
# define constants
INPUT_SIZE = 64*24
DEGREE = 3
LATENT_SIZE = 4*24
gnrt_start = '1970-01-01 00:00:00'
gnrt_end = '2020-12-31 16:00:00'

# Parameters
input_shape = INPUT_SIZE
latent_dim = None
latent_filter = 20
interim_filters = 20

# training hyperparameters
learning_rate = 0.001
epochs = 500
batch_size = 32

prior_dist_type = 'Seasonal'
activate_phase_shift = True

os.makedirs('results', exist_ok=True)
results_directory = f'results/training_run_{prior_dist_type}_prior_{activate_phase_shift}_phase_shift_{epochs}_epochs'

# %% [markdown]
# ### Data Processing

# %%
# %matplotlib notebook

os.makedirs('data/processed', exist_ok=True)
os.makedirs('images', exist_ok=True)

set_seed(42)
df_list = []
for year in range(1970, 2021, 3):
    ds = xr.open_dataset(f'data/raw/phoenix/t2m_{year}_{year+2}/data_stream-oper_stepType-instant.nc')
    df = pd.DataFrame(index=ds['valid_time'], data=ds['t2m'][:, 0, 0])
    df.index = pd.to_datetime(df.index)
    df_list.append(df)

df = pd.concat(df_list)
df.columns = ['Observed']

# convert Kelvin to Celsius
df.Observed = df.Observed - 273.15
df_mst = df.copy()
df_mst.index = df_mst.index.shift(-7, freq='h')
df_mst = df_mst.iloc[7:]

# Calculate the slope of the temperature trend across yearly averages
df_yearly = df_mst.resample('YS').mean()
slope = np.polyfit(df_yearly.index.year, df_yearly['Observed'], 1)[0]
# Add climate adjusted data to dataframe
df_mst['Climate Adjusted'] = df_mst['Observed'] - slope*(df_mst.index.year-2020)

df_yearly = df_mst.resample('YS').mean()
df_yearly.plot()
plt.title('Annual Average Temperature in Phoenix')
plt.ylabel('Temperature (°C)')
plt.xlabel('Year')
plt.gca().get_lines()[1].set_linestyle('--')
plt.gca().get_lines()[0].set_color('orange')
plt.gca().get_lines()[1].set_color('red')
plt.legend()
plt.savefig('images/long_term_trend.png', dpi=300)
plt.close()

# Save the processed data
df_mst.to_csv('data/processed/observed_time_series.csv')

offset = round(df_mst['Climate Adjusted'].mean(), 8)
print('offset: ', offset)
scale = round(df_mst['Climate Adjusted'].std(), 8)
print('scale:  ', scale)
dft = (df_mst['Climate Adjusted']-offset)/scale

data_params = pd.Series({'offset': offset, 'scale': scale}, name='values')
data_params.to_csv('data/data_params.csv')

values = dft.values.squeeze()  # (T,) shape if single column
timestamps = dft.index

# Parameters
window_size = INPUT_SIZE  # 64 days
hop_size = int(window_size/4)     # 16 days
total_hours = len(values)

# Generate overlapping windows
X = []
index = []

while True:
    # Random phase shift between -12 and +12 hours
    phase_shift = np.random.randint(-12, 13) # replace with phase_shift = 0
    start = len(X) * hop_size
    shifted_start = start + phase_shift
    # Ensure shifted_start is within valid range
    shifted_start = max(0, min(shifted_start, total_hours - window_size))
    end = shifted_start + window_size
    if end > total_hours:
        break
    X.append(values[shifted_start:end])
    index.append(timestamps[shifted_start])
    if end == total_hours:
        break

X = np.array(X)  # Shape: (num_chunks, window_size)
index = pd.to_datetime(index)

# Create DataFrame with timestamp index
dft_reshaped = pd.DataFrame(data=X, index=index)

# Keep only rows where the index month is January
# dft_reshaped = dft_reshaped[dft_reshaped.index.month.isin([1])]

# Shuffle rows reproducibly
dft_reshaped = dft_reshaped.sample(frac=1)

# Save to CSV
dft_reshaped.to_csv('data/processed/phoenix_64days.csv')
# Out:
# <div id='479fbc8c-8c90-4ccc-8d07-d11b111427f3'></div>
# offset:  23.27571895
# scale:   9.89200131

# %% [markdown]
# ## Model

# %%
# import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

# Build the encoder
def build_encoder():
    inputs = layers.Input(shape=(input_shape,))
    x = layers.Reshape((-1, 1))(inputs)
    x = layers.Conv1D(interim_filters, 5, strides=3, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(2*latent_filter, 3, strides=2, padding='same')(x)
    z_mean = x[: ,:, :latent_filter]
    z_log_var = x[:, :, latent_filter:]
    z = Sampling()([z_mean, z_log_var])
    encoder = models.Model(inputs, [z_mean, z_log_var, z], name='encoder')
    return encoder

# Build the decoder
def build_decoder():
    latent_inputs = layers.Input(shape=(latent_dim, latent_filter))
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(latent_inputs)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(1, 5, strides=3, padding='same')(x)
    outputs = layers.Reshape((-1,))(x)
    decoder = models.Model(latent_inputs, outputs, name='decoder')
    return decoder

def build_seasonal_prior():
    seasonal_inputs = layers.Input(shape=(None, 2*DEGREE,))
    x = layers.Dense(2*latent_filter, use_bias=False)(seasonal_inputs)
    z_mean = x[:, :, :latent_filter]
    z_log_var = x[:, :, latent_filter:]
    z = Sampling()([z_mean, z_log_var])
    seasonal_prior = models.Model(seasonal_inputs, [z_mean, z_log_var, z], name='seasonal_prior')
    return seasonal_prior

class VAE(models.Model):
    def __init__(self, encoder, decoder, prior, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.prior = prior # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        self.noise_log_var = self.add_weight(name='var', shape=(1,), initializer='zeros', trainable=True)

    @tf.function
    def vae_loss(self, data):
        values = data[0]
        seasonal = data[1]
        z_mean, z_log_var, z = self.encoder(values)
        reconstructed = self.decoder(z)
        reconstruction_loss = -log_lik_normal_sum(values, reconstructed, self.noise_log_var)/INPUT_SIZE
        seasonal_z_mean, seasonal_z_log_var, _ = self.prior(seasonal) # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        kl_loss_z = kl_divergence_sum(z_mean, z_log_var, seasonal_z_mean, seasonal_z_log_var)/INPUT_SIZE # NOTE COMMENT THIS LINE OUT IF NO SEASONAL PRIOR IS USED
        kl_loss_z = kl_divergence_standard_normal(z_mean, z_log_var) / INPUT_SIZE # Standard normal prior: mean=0, log_var=0 (=> std=1)
        return reconstruction_loss, kl_loss_z

    def train_step(self, data):
        with tf.GradientTape() as tape:
            reconstruction_loss, kl_loss_z = self.vae_loss(data)
            total_loss = reconstruction_loss + kl_loss_z
        
        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        
        return {'loss': total_loss}
    
    def test_step(self, data):
        reconstruction_loss, kl_loss_z = self.vae_loss(data)

        return {'loss': reconstruction_loss + kl_loss_z, 'recon': reconstruction_loss, 'kl': kl_loss_z}

    def call(self, inputs):
        _, _, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        return reconstructed

# %% [markdown]
# ## Training

# %%
os.makedirs('model', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

fourier = lambda x: np.stack(
    [np.sin(2*np.pi*i*x) for i in range(1, DEGREE+1)] + 
    [np.cos(2*np.pi*i*x) for i in range(1, DEGREE+1)], axis=-1)

starting_day = np.array(data.index.dayofyear)[:, np.newaxis] - 1
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)

training_ratio = 0.8

train = data.values[:int(len(data)*training_ratio)]
test = data.values[int(len(data)*training_ratio):]
train_seasonal = seasonal_data[:int(len(data)*training_ratio)]
test_seasonal = seasonal_data[int(len(data)*training_ratio):]

# convert to tensors
train_tensor = tf.convert_to_tensor(train, dtype=tf.float32)
test_tensor = tf.convert_to_tensor(test, dtype=tf.float32)
train_seasonal_tensor = tf.convert_to_tensor(train_seasonal, dtype=tf.float32)
test_seasonal_tensor = tf.convert_to_tensor(test_seasonal, dtype=tf.float32)

encoder = build_encoder()
encoder.summary()
decoder = build_decoder()
decoder.summary()
seasonal_prior = build_seasonal_prior()
seasonal_prior.summary()

# Create the VAE model
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
optimizer = Adam(learning_rate=learning_rate)
vae.compile(optimizer=optimizer)

history = vae.fit(
    train_tensor, train_seasonal_tensor, 
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(test_tensor, test_seasonal_tensor),)

# Save model weights
_ = vae(train_tensor[:1])  # Call model once to build it
vae.save_weights('model/model_weights.weights.h5')

# Model reconstruction accuracy
print('noise emission sigma: ', np.exp(0.5*vae.noise_log_var)[0])

# Loss on validation data
recon_loss, kl_loss = vae.vae_loss((test_tensor, test_seasonal_tensor))
recon_loss = recon_loss.numpy()
kl_loss = kl_loss.numpy()
total_loss = recon_loss + kl_loss

# Save loss information as a dataframe
summary_df = pd.DataFrame({
    'Reconstruction loss': [recon_loss],
    'KL loss': [kl_loss],
    'Total loss': [total_loss]
})
summary_df.to_csv('data/train_summary.csv', index=False)

print('Reconstruction loss: ', recon_loss)
print('KL loss:             ', kl_loss)
print('Total loss:          ', total_loss)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9       │ (None, 1536)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1536, 1)   │          0 │ input_layer_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 512, 20)   │        120 │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 256, 20)   │      1,220 │ conv1d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 128, 20)   │      1,220 │ conv1d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 64, 20)    │      1,220 │ conv1d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 32, 20)    │      1,220 │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_23 (Conv1D)  │ (None, 16, 40)    │      2,440 │ conv1d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_12         │ (None, 16, 20)    │          0 │ conv1d_23[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_13         │ (None, 16, 20)    │          0 │ conv1d_23[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_6          │ (None, 16, 20)    │          0 │ get_item_12[0][0… │
# │ (Sampling)          │                   │            │ get_item_13[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,440 (29.06 KB)
#  Trainable params: 7,440 (29.06 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)     │ (None, None, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_18             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_19             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_20             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_21             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_22             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_23             │ (None, None, 1)        │           101 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_7 (Reshape)             │ (None, None)           │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,201 (24.22 KB)
#  Trainable params: 6,201 (24.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "seasonal_prior"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, None, 6)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, None, 40)  │        240 │ input_layer_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_14         │ (None, None, 20)  │          0 │ dense_3[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_15         │ (None, None, 20)  │          0 │ dense_3[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_7          │ (None, None, 20)  │          0 │ get_item_14[0][0… │
# │ (Sampling)          │                   │            │ get_item_15[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 240 (960.00 B)
#  Trainable params: 240 (960.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\optimizers\base_optimizer.py:731: UserWarning: Gradients do not exist for variables ['kernel'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3804 - val_loss: 1.4866 - val_recon: 1.4866 - val_kl: 1.4182e-06
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3797 - val_loss: 1.4854 - val_recon: 1.4854 - val_kl: 8.0482e-08
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3795 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.3756e-08
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3793 - val_loss: 1.4844 - val_recon: 1.4844 - val_kl: 3.2208e-09
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3791 - val_loss: 1.4844 - val_recon: 1.4844 - val_kl: 3.7738e-08
# Epoch 6/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3790 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 9.3365e-08
# Epoch 7/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3790 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.0501e-07
# Epoch 8/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3790 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.4959e-07
# Epoch 9/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3789 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 1.3240e-07
# Epoch 10/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3789 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.0103e-07
# Epoch 11/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3789 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1471e-07
# Epoch 12/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3789 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 8.9426e-08
# Epoch 13/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4850 - val_recon: 1.4850 - val_kl: 9.2182e-08
# Epoch 14/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3789 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.0058e-07
# Epoch 15/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 7.8231e-08
# Epoch 16/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3789 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-08
# Epoch 17/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 7.8231e-08
# Epoch 18/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3789 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.0896e-07
# Epoch 19/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 7.8231e-08
# Epoch 20/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 4.7497e-08
# Epoch 21/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 6.1467e-08
# Epoch 22/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-08
# Epoch 23/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 6.1467e-08
# Epoch 24/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 6.9849e-08
# Epoch 25/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 5.5879e-08
# Epoch 26/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 4.1910e-08
# Epoch 27/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 7.8231e-08
# Epoch 28/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.0291e-08
# Epoch 29/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 3.9116e-08
# Epoch 30/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-08
# Epoch 31/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.3085e-08
# Epoch 32/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4845 - val_recon: 1.4845 - val_kl: 4.1910e-08
# Epoch 33/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.3528e-08
# Epoch 34/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4844 - val_recon: 1.4844 - val_kl: 3.6322e-08
# Epoch 35/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 6.4261e-08
# Epoch 36/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.0291e-08
# Epoch 37/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.8673e-08
# Epoch 38/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 4.1910e-08
# Epoch 39/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 4.7497e-08
# Epoch 40/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4844 - val_recon: 1.4844 - val_kl: 2.5146e-08
# Epoch 41/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 3.9116e-08
# Epoch 42/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 43/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 44/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 45/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 46/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 3.6322e-08
# Epoch 47/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 48/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 49/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 3.6322e-08
# Epoch 50/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 51/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 52/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.3528e-08
# Epoch 53/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 54/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.1176e-08
# Epoch 55/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 56/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.9558e-08
# Epoch 57/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4845 - val_recon: 1.4845 - val_kl: 1.9558e-08
# Epoch 58/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 2.5146e-08
# Epoch 59/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.9558e-08
# Epoch 60/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 61/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.3970e-08
# Epoch 62/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 8.3819e-09
# Epoch 63/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 64/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 65/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 66/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 67/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 5.3085e-08
# Epoch 68/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 3.0734e-08
# Epoch 69/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 3.6322e-08
# Epoch 70/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.0291e-08
# Epoch 71/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 3.6322e-08
# Epoch 72/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.9558e-08
# Epoch 73/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 4.1910e-08
# Epoch 74/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 75/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 76/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 77/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.9558e-08
# Epoch 78/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 79/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 80/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-08
# Epoch 81/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 3.3528e-08
# Epoch 82/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.0734e-08
# Epoch 83/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 84/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 6.7055e-08
# Epoch 85/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 4.4703e-08
# Epoch 86/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 87/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 1.1176e-08
# Epoch 88/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 1.6764e-08
# Epoch 89/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.8673e-08
# Epoch 90/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.8673e-08
# Epoch 91/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.9116e-08
# Epoch 92/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-08
# Epoch 93/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1735e-07
# Epoch 94/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 1.1176e-07
# Epoch 95/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 9.4995e-08
# Epoch 96/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-08
# Epoch 97/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.9407e-08
# Epoch 98/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 7.5437e-08
# Epoch 99/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 4.4703e-08
# Epoch 100/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 9.4995e-08
# Epoch 101/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 3.9116e-08
# Epoch 102/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-08
# Epoch 103/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-08
# Epoch 104/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 8.1025e-08
# Epoch 105/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 8.3819e-08
# Epoch 106/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.0617e-07
# Epoch 107/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 5.5879e-08
# Epoch 108/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.9116e-08
# Epoch 109/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-08
# Epoch 110/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 4.4703e-08
# Epoch 111/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 3.9116e-08
# Epoch 112/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.0734e-08
# Epoch 113/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.3528e-08
# Epoch 114/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: 2.5146e-08
# Epoch 115/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 7.2643e-08
# Epoch 116/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 4.4703e-08
# Epoch 117/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-08
# Epoch 118/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.9116e-08
# Epoch 119/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.0291e-08
# Epoch 120/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-08
# Epoch 121/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 4.4703e-08
# Epoch 122/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.3085e-08
# Epoch 123/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-08
# Epoch 124/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 7.5437e-08
# Epoch 125/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 4.4703e-08
# Epoch 126/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-08
# Epoch 127/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.5146e-08
# Epoch 128/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-08
# Epoch 129/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 130/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-08
# Epoch 131/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 6.7055e-08
# Epoch 132/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.0058e-07
# Epoch 133/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3787 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 6.4261e-08
# Epoch 134/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 5.0291e-08
# Epoch 135/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.0291e-08
# Epoch 136/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 3.6322e-08
# Epoch 137/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 138/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 139/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 140/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-08
# Epoch 141/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.2352e-08
# Epoch 142/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 143/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.9116e-08
# Epoch 144/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-08
# Epoch 145/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.5146e-08
# Epoch 146/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 147/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 148/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 149/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.2352e-08
# Epoch 150/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 151/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 152/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 5.5879e-09
# Epoch 153/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 154/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.2352e-08
# Epoch 155/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-08
# Epoch 156/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 157/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.9558e-08
# Epoch 158/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 159/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: -0.0000e+00
# Epoch 160/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 161/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: -0.0000e+00
# Epoch 162/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 163/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 164/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 165/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 166/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 167/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 168/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 169/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: -0.0000e+00
# Epoch 170/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 171/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 172/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: -0.0000e+00
# Epoch 173/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 174/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 175/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 176/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 177/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.5146e-08
# Epoch 178/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 179/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.5146e-08
# Epoch 180/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 181/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 182/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 183/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 184/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 185/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.5146e-08
# Epoch 186/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 187/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 188/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.2352e-08
# Epoch 189/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 190/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 191/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 192/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 193/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 3.0734e-08
# Epoch 194/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 195/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.2352e-08
# Epoch 196/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.2352e-08
# Epoch 197/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 198/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 199/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.9558e-08
# Epoch 200/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 201/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 202/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 203/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 204/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 205/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 206/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 207/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 208/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 209/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 210/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 211/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 212/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 213/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 214/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 215/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 216/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 217/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4846 - val_recon: 1.4846 - val_kl: -0.0000e+00
# Epoch 218/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 219/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 220/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 221/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 222/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 223/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 224/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 225/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 226/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 227/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 228/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 229/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.9558e-08
# Epoch 230/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 231/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 232/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 233/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 234/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 235/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.5146e-08
# Epoch 236/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 237/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 238/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 239/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 240/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 241/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 242/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 243/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 244/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 245/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 246/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 247/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 248/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 249/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 250/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 251/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 252/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 253/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 254/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 255/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 256/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 257/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 258/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 259/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 260/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-09
# Epoch 261/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 262/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 263/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 264/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 265/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 266/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 267/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 268/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 269/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 270/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 271/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 272/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 273/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: -0.0000e+00
# Epoch 274/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 275/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 276/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 277/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 278/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.6764e-08
# Epoch 279/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.1176e-08
# Epoch 280/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 281/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 282/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 283/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 8.3819e-09
# Epoch 284/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-09
# Epoch 285/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 286/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 287/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 288/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 289/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-09
# Epoch 290/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 291/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 292/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 2.7940e-09
# Epoch 293/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: -0.0000e+00
# Epoch 294/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 295/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 296/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 297/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 298/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 299/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 300/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 301/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 302/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 303/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 304/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 305/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 306/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 307/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 308/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 309/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 310/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 311/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 312/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 5.5879e-09
# Epoch 313/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 314/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 315/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 316/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 317/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 318/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3788 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 319/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 320/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 321/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 322/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 323/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 324/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 325/500
# ...
# Epoch 379/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: -0.0000e+00
# Epoch 380/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 381/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 382/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 383/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3787 - val_loss: 1.4847 - val_recon: 1.4847 - val_kl: 1.3970e-08
# Epoch 384/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 385/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 386/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 387/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 388/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 389/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 390/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 391/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 392/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 393/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 394/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 395/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 396/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 397/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 398/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 399/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 400/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 401/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 402/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 403/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 404/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 405/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 406/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 407/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 408/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 409/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 410/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 411/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 412/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 413/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 414/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.9558e-08
# Epoch 415/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 416/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 417/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 418/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 419/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 420/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 421/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.3970e-08
# Epoch 422/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 423/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 424/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 425/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 426/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 427/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 428/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 429/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 430/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 431/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 432/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 433/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 434/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 435/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 436/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.6764e-08
# Epoch 437/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 438/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4849 - val_recon: 1.4849 - val_kl: 2.7940e-09
# Epoch 439/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 440/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 441/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 442/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 443/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 444/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 445/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 446/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 447/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 448/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 449/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 450/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 451/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 452/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 453/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 454/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 455/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 456/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 457/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 458/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 459/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 460/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 461/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 462/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 463/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 464/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 465/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 466/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 467/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 468/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 469/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 470/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 471/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 472/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 473/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 474/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 475/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 476/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 477/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 478/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 5.5879e-09
# Epoch 479/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 480/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 481/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 482/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 483/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 484/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 485/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 486/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 487/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 488/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 8.3819e-09
# Epoch 489/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 490/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 491/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 492/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 493/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 494/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 495/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 496/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 497/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 1.1176e-08
# Epoch 498/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: 2.7940e-09
# Epoch 499/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# Epoch 500/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3787 - val_loss: 1.4848 - val_recon: 1.4848 - val_kl: -0.0000e+00
# noise emission sigma:  1.0055137
# Reconstruction loss:  1.4163216
# KL loss:              5.820766e-09
# Total loss:           1.4163216

# %% [markdown]
# ## Generating new data

# %%
# %matplotlib notebook

os.makedirs('data/processed', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
seasonal_prior = build_seasonal_prior()
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
vae.compile()

starting_day = np.array(data.index.dayofyear)[:, np.newaxis] - 1
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)

gen_dataset = data.values
gen_dataset_seasonal = seasonal_data

# convert to tensors
gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32)
gen_dataset_seasonal_tensor = tf.convert_to_tensor(gen_dataset_seasonal, dtype=tf.float32)

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)

# set figure size
plt.figure(figsize=(15, 5))
# boxplot of encoded_mean
plt.subplot(1, 2, 1)
plt.boxplot(encoded_mean.numpy().reshape(-1, latent_filter))
plt.title('Encoded Mean')

# boxplot of encoded_log_var
plt.subplot(1, 2, 2)
plt.boxplot(encoded_log_var.numpy().reshape(-1, latent_filter))
plt.title('Encoded Log Variance')

plt.savefig("images/encoded_log_variance.png", dpi=300)

start_date = '1970-01-01 00:00:00'
end_date = '2020-12-31 16:00:00' 
dt = pd.date_range(start=start_date, end=end_date, freq='h')

gen_seasonal_inputs = fourier((dt.dayofyear[::LATENT_SIZE])/365)[np.newaxis]
_, _, z_gen = seasonal_prior(gen_seasonal_inputs)

gen_mean = decoder(z_gen).numpy()
noise = np.random.normal(size=gen_mean.shape)*np.exp(0.5*vae.noise_log_var[0].numpy())
gen = gen_mean + noise
n_latents = int(np.ceil(len(dt) / LATENT_SIZE))
z_gen = np.random.normal(size=(1, n_latents, latent_filter)).astype(np.float32)

gen_mean = decoder(z_gen).numpy()

data_params = pd.read_csv('data/data_params.csv', index_col=0)
offset = data_params.loc['offset', 'values']
scale = data_params.loc['scale', 'values']

gen_series = pd.Series(gen[0, :len(dt)]*scale + offset, index=dt)
gen_series = gen_series.rename('temperature')
gen_series = gen_series.to_frame()
gen_series.index.name = 'time'

# Add back seasonal cycle
df_obs = pd.read_csv('data/processed/observed_time_series.csv', index_col=0, parse_dates=True)
df_obs['weekofyear'] = df_obs.index.isocalendar().week
weekly_climatology = df_obs.groupby('weekofyear')['Observed'].mean()

# Map each hour in generated time series to its weekly mean
week_numbers = gen_series.index.isocalendar().week
seasonal_cycle = np.array([weekly_climatology[w] for w in week_numbers])
gen_series['temperature'] += seasonal_cycle

gen_series.to_csv('data/processed/generated.csv')

print(f"Succesfully generated time series of length: {len(gen_series.iloc[:,0])}")

gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')
plt.savefig('images/generated_monthly_avg.png', dpi=300)
# Out:
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# <div id='30743bca-380f-46b0-b818-a9ce48a4b916'></div>
# Succesfully generated time series of length: 447065
# C:\Users\lokes\AppData\Local\Temp\ipykernel_32200\1397737070.py:95: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')

# %% [markdown]
# ### Latent Space Analysis

# %%
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

fourier = lambda x: np.stack(
    [np.sin(2*np.pi*i*x) for i in range(1, DEGREE+1)] + 
    [np.cos(2*np.pi*i*x) for i in range(1, DEGREE+1)], axis=-1)

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
seasonal_prior = build_seasonal_prior()
vae = VAE(encoder=encoder, decoder=decoder, prior=seasonal_prior)
# optimizer = Adam(learning_rate=learning_rate)
vae.compile()

starting_day = np.array(data.index.dayofyear)[:, np.newaxis] - 1
data_days = (starting_day + np.arange(0, INPUT_SIZE//24, LATENT_SIZE//24))%365
seasonal_data = fourier(data_days/365)

#------------------------------------------------------------------------------
gen_dataset = data.values
gen_dataset_seasonal = seasonal_data

gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32) # convert to tensors
gen_dataset_seasonal_tensor = tf.convert_to_tensor(gen_dataset_seasonal, dtype=tf.float32)
#------------------------------------------------------------------------------

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)
# Out:
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Latent Space Plotting Stuff

# %%
# %matplotlib notebook

# Setup
os.makedirs('images', exist_ok=True)

# Load data
latent_vectors = np.load("data/processed/latent_vectors.npy")
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

if latent_vectors.shape[0] != data.shape[0]:
    print(f"Mismatch: {latent_vectors.shape[0]} latent vectors vs {data.shape[0]} rows in CSV. Trimming data.")
    data = data.iloc[:latent_vectors.shape[0]]

# Colour labels
mean_temps = data.mean(axis=1)
day_of_year_frac = data.index.dayofyear / 365.0
hour_of_day_frac = data.index.hour / 24.0

# Flatten latent vectors
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)

# Reduce dimensions
print("First performing a PCA")
pca = PCA(n_components=2)
pca_latents = pca.fit_transform(flat_latents)
print("PCA done")

print("Now performing t-SNE")
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_latents = tsne.fit_transform(flat_latents)
print("t-SNE done")

print("Now performing UMAP")
umap_model = umap.UMAP(n_components=2, random_state=42)
umap_latents = umap_model.fit_transform(flat_latents)
print("UMAP done")

# Helper for plotting
colorings = {
    "Mean Temp": mean_temps,
    "Day of Year (Fraction)": day_of_year_frac,
    "Hour of Day (Fraction)": hour_of_day_frac
}

reduced_spaces = {
    "Raw": flat_latents,
    "PCA": pca_latents,
    "t-SNE": tsne_latents,
    "UMAP": umap_latents
}

# Plot
fig, axs = plt.subplots(4, 3, figsize=(18, 20))

# Define colormaps for each coloring
cmap_dict = {
    "Mean Temp": "coolwarm",
    "Day of Year (Fraction)": "viridis",
    "Hour of Day (Fraction)": "plasma"
}

for i, (method_name, embedding) in enumerate(reduced_spaces.items()):
    for j, (label_name, label_values) in enumerate(colorings.items()):
        print(f"Plotting {method_name} coloured by {label_name}")
        ax = axs[i, j]
        cmap = cmap_dict.get(label_name, "viridis")
        scatter = ax.scatter(embedding[:, 0], embedding[:, 1], c=label_values, cmap=cmap, s=8, alpha=0.7)
        ax.set_title(f"{method_name} - Coloured by {label_name}")
        ax.set_xticks([])
        ax.set_yticks([])
        fig.colorbar(scatter, ax=ax, fraction=0.03, pad=0.01)

plt.tight_layout()
plt.savefig("images/latent_space_analysis.png", dpi=500)
plt.close()
print("Saved mega plot to images/latent_space_analysis.png")
# Out:
# First performing a PCA
# PCA done
# Now performing t-SNE
# t-SNE done
# Now performing UMAP
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP done
# <div id='1842d870-bffc-4acf-8a9d-906f75c60808'></div>
# Plotting Raw coloured by Mean Temp
# Plotting Raw coloured by Day of Year (Fraction)
# Plotting Raw coloured by Hour of Day (Fraction)
# Plotting PCA coloured by Mean Temp
# Plotting PCA coloured by Day of Year (Fraction)
# Plotting PCA coloured by Hour of Day (Fraction)
# Plotting t-SNE coloured by Mean Temp
# Plotting t-SNE coloured by Day of Year (Fraction)
# Plotting t-SNE coloured by Hour of Day (Fraction)
# Plotting UMAP coloured by Mean Temp
# Plotting UMAP coloured by Day of Year (Fraction)
# Plotting UMAP coloured by Hour of Day (Fraction)
# Saved mega plot to images/latent_space_analysis.png

# %% [markdown]
# ## Wrap up

# %%
# Define paths
folders_to_move = [
    'images',
    'model',
    os.path.join('data', 'processed')
]

files_to_move = [
    os.path.join('data', 'data_params.csv'),
    os.path.join('data', 'train_summary.csv')
]

# Create the results directory if it doesn't exist
os.makedirs(results_directory, exist_ok=True)

# Move folders
for folder in folders_to_move:
    if os.path.isdir(folder):
        dest_folder = os.path.join(results_directory, os.path.basename(folder))
        shutil.move(folder, dest_folder)
        print(f"Moved folder '{folder}' to '{dest_folder}'")
    else:
        print(f"Folder not found: {folder}")

# Move files
for file in files_to_move:
    if os.path.isfile(file):
        dest_file = os.path.join(results_directory, os.path.basename(file))
        shutil.move(file, dest_file)
        print(f"Moved file '{file}' to '{dest_file}'")
    else:
        print(f"File not found: {file}")

# Delete __pycache__ folder if it exists
pycache_folder = '__pycache__'
if os.path.isdir(pycache_folder):
    shutil.rmtree(pycache_folder)
    print(f"Deleted folder '{pycache_folder}'")
# Out:
# Moved folder 'images' to 'results/training_run_Seasonal_prior_True_phase_shift_500_epochs\images'
# Moved folder 'model' to 'results/training_run_Seasonal_prior_True_phase_shift_500_epochs\model'
# Moved folder 'data\processed' to 'results/training_run_Seasonal_prior_True_phase_shift_500_epochs\processed'
# Moved file 'data\data_params.csv' to 'results/training_run_Seasonal_prior_True_phase_shift_500_epochs\data_params.csv'
# Moved file 'data\train_summary.csv' to 'results/training_run_Seasonal_prior_True_phase_shift_500_epochs\train_summary.csv'
