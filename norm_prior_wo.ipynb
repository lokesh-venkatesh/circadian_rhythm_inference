# %% [markdown]
# # Training Run - Seasonal Prior & phase shifted inputs

# %% [markdown]
# #### Importing Libraries:

# %%
import subprocess
import os
import sys
import argparse
import shutil
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap.umap_ as umap
import os

from utils import *

# %% [markdown]
# ### Config

# %%
# define constants
INPUT_SIZE = 64*24
DEGREE = 3
LATENT_SIZE = 4*24
gnrt_start = '1970-01-01 00:00:00'
gnrt_end = '2020-12-31 16:00:00'

# Parameters
input_shape = INPUT_SIZE
latent_dim = None
latent_filter = 20
interim_filters = 20

# training hyperparameters
learning_rate = 0.001
epochs = 500
batch_size = 32

prior_dist_type = 'Normal'
activate_phase_shift = False

os.makedirs('summary', exist_ok=True)
results_directory = f'summary/training_run_{prior_dist_type}_prior_{activate_phase_shift}_phase_shift_{epochs}_epochs'

# %% [markdown]
# ### Data Processing

# %%
# %matplotlib notebook

os.makedirs('data/processed', exist_ok=True)
os.makedirs('images', exist_ok=True)

set_seed()
df_list = []
for year in range(1970, 2021, 3):
    ds = xr.open_dataset(f'data/raw/phoenix/t2m_{year}_{year+2}/data_stream-oper_stepType-instant.nc')
    df = pd.DataFrame(index=ds['valid_time'], data=ds['t2m'][:, 0, 0])
    df.index = pd.to_datetime(df.index)
    df_list.append(df)

df = pd.concat(df_list)
df.columns = ['Observed']

# convert Kelvin to Celsius
df.Observed = df.Observed - 273.15
df_mst = df.copy()
df_mst.index = df_mst.index.shift(-7, freq='h')
df_mst = df_mst.iloc[7:]

# Calculate the slope of the temperature trend across yearly averages
df_yearly = df_mst.resample('YS').mean()
slope = np.polyfit(df_yearly.index.year, df_yearly['Observed'], 1)[0]
# Add climate adjusted data to dataframe
df_mst['Climate Adjusted'] = df_mst['Observed'] - slope*(df_mst.index.year-2020)

df_yearly = df_mst.resample('YS').mean()
df_yearly.plot()
plt.title('Annual Average Temperature in Phoenix')
plt.ylabel('Temperature (°C)')
plt.xlabel('Year')
plt.gca().get_lines()[1].set_linestyle('--')
plt.gca().get_lines()[0].set_color('orange')
plt.gca().get_lines()[1].set_color('red')
plt.legend()
plt.savefig('images/long_term_trend.png', dpi=300)
plt.close()

# Compute the week number for each timestamp
df_mst['weekofyear'] = df_mst.index.isocalendar().week

# Group by week number and compute climatological weekly averages
weekly_climatology = df_mst.groupby('weekofyear')['Observed'].mean()

# Map each timestamp to the corresponding weekly climatological mean
df_mst['Weekly Mean'] = df_mst['weekofyear'].map(weekly_climatology)

# Subtract the seasonal cycle
df_mst['Deseasonalized'] = df_mst['Observed'] - df_mst['Weekly Mean']

# Plot average of deseasonalized data by week
df_mst['Deseasonalized'].groupby(df_mst['weekofyear']).mean().plot()
plt.title("Weekly Averages After Deseasonalization")
plt.xlabel("Week of Year")
plt.ylabel("Temperature Anomaly (°C)")
plt.grid()
plt.savefig('images/long_term_trend.png', dpi=300)
plt.close()

# Save the processed data
df_mst.to_csv('data/processed/observed_time_series.csv')

offset = round(df_mst['Climate Adjusted'].mean(), 8)
print('offset: ', offset)
scale = round(df_mst['Climate Adjusted'].std(), 8)
print('scale:  ', scale)
dft = (df_mst['Climate Adjusted']-offset)/scale

data_params = pd.Series({'offset': offset, 'scale': scale}, name='values')
data_params.to_csv('data/data_params.csv')

values = dft.values.squeeze()  # (T,) shape if single column
timestamps = dft.index

# Parameters
window_size = INPUT_SIZE  # 64 days
hop_size = int(window_size/4)     # 16 days
total_hours = len(values)

# Generate overlapping windows
X = []
index = []

while True:
    start = len(X)*hop_size
    start = max(0, min(start, total_hours - window_size)) # ensure within bounds
    end = start + window_size
    if end > total_hours:
        break
    X.append(values[start:end])
    index.append(timestamps[start])
    if end == total_hours:
        break

X = np.array(X)  # Shape: (num_chunks, window_size)
index = pd.to_datetime(index)

# Create DataFrame with timestamp index
dft_reshaped = pd.DataFrame(data=X, index=index)

# Keep only rows where the index month is January
# dft_reshaped = dft_reshaped[dft_reshaped.index.month.isin([1])]

# Shuffle rows reproducibly
dft_reshaped = dft_reshaped.sample(frac=1)

# Save to CSV
dft_reshaped.to_csv('data/processed/phoenix_64days.csv')
# Out:
# <div id='b373286d-ed60-42e5-a7af-78d573a79bef'></div>
# <div id='b9fd53b1-b30a-4d9f-a804-4d69e4f3cb26'></div>
# offset:  23.27571895
# scale:   9.89200131

# %% [markdown]
# ## Model

# %%
# Build the encoder
def build_encoder():
    inputs = layers.Input(shape=(input_shape,))
    x = layers.Reshape((-1, 1))(inputs)
    x = layers.Conv1D(interim_filters, 5, strides=3, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(2*latent_filter, 3, strides=2, padding='same')(x)
    z_mean = x[: ,:, :latent_filter]
    z_log_var = x[:, :, latent_filter:]
    z = Sampling()([z_mean, z_log_var])
    encoder = models.Model(inputs, [z_mean, z_log_var, z], name='encoder')
    encoder.summary()
    return encoder

# Build the decoder
def build_decoder():
    latent_inputs = layers.Input(shape=(latent_dim, latent_filter))
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(latent_inputs)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(interim_filters, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1DTranspose(1, 5, strides=3, padding='same')(x)
    outputs = layers.Reshape((-1,))(x)
    decoder = models.Model(latent_inputs, outputs, name='decoder')
    decoder.summary()
    return decoder

class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.noise_log_var = self.add_weight(name='var', shape=(1,), initializer='zeros', trainable=True)

    @tf.function
    def vae_loss(self, data):
        values = data  # Use only values if no seasonal prior is used
        z_mean, z_log_var, z = self.encoder(values)
        reconstructed = self.decoder(z)
        reconstruction_loss = -log_lik_normal_sum(values, reconstructed, self.noise_log_var)/INPUT_SIZE
        kl_loss_z = kl_divergence_standard_normal(z_mean, z_log_var) / INPUT_SIZE # Standard normal prior: mean=0, log_var=0 (=> std=1)
        return reconstruction_loss, kl_loss_z

    def train_step(self, data):
        with tf.GradientTape() as tape:
            reconstruction_loss, kl_loss_z = self.vae_loss(data)
            total_loss = reconstruction_loss + kl_loss_z
        
        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        
        return {'loss': total_loss}
    
    def test_step(self, data):
        reconstruction_loss, kl_loss_z = self.vae_loss(data)

        return {'loss': reconstruction_loss + kl_loss_z, 'recon': reconstruction_loss, 'kl': kl_loss_z}

    def call(self, inputs):
        _, _, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        return reconstructed

# %% [markdown]
# ## Training

# %%
os.makedirs('model', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

training_ratio = 0.8

train = data.values[:int(len(data)*training_ratio)]
test = data.values[int(len(data)*training_ratio):]

train_tensor = tf.convert_to_tensor(train, dtype=tf.float32)
test_tensor = tf.convert_to_tensor(test, dtype=tf.float32)

encoder = build_encoder()
decoder = build_decoder()
vae = VAE(encoder=encoder, decoder=decoder)
optimizer = Adam(learning_rate=learning_rate)
vae.compile(optimizer=optimizer)

history = vae.fit(
    train_tensor, 
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(test_tensor, ),
)


# Save model weights
_ = vae(train_tensor[:1])  # Call model once to build it
vae.save_weights('model/model_weights.weights.h5')

# Model reconstruction accuracy
print('noise emission sigma: ', np.exp(0.5*vae.noise_log_var)[0])

# Loss on validation data
# recon_loss, kl_loss = vae.vae_loss((test_tensor, test_seasonal_tensor))
recon_loss, kl_loss = vae.vae_loss(test_tensor)
recon_loss = recon_loss.numpy()
kl_loss = kl_loss.numpy()
total_loss = recon_loss + kl_loss

# Save loss information as a dataframe
summary_df = pd.DataFrame({
    'Reconstruction loss': [recon_loss],
    'KL loss': [kl_loss],
    'Total loss': [total_loss]
})
summary_df.to_csv('data/train_summary.csv', index=False)

print('Reconstruction loss: ', recon_loss)
print('KL loss:             ', kl_loss)
print('Total loss:          ', total_loss)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 1536)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1536, 1)   │          0 │ input_layer_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 512, 20)   │        120 │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 256, 20)   │      1,220 │ conv1d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 128, 20)   │      1,220 │ conv1d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 64, 20)    │      1,220 │ conv1d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 32, 20)    │      1,220 │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_23 (Conv1D)  │ (None, 16, 40)    │      2,440 │ conv1d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 16, 20)    │          0 │ conv1d_23[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 16, 20)    │          0 │ conv1d_23[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_3          │ (None, 16, 20)    │          0 │ get_item_6[0][0], │
# │ (Sampling)          │                   │            │ get_item_7[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,440 (29.06 KB)
#  Trainable params: 7,440 (29.06 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, None, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_18             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_19             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_20             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_21             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_22             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_23             │ (None, None, 1)        │           101 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_7 (Reshape)             │ (None, None)           │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,201 (24.22 KB)
#  Trainable params: 6,201 (24.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.3543 - val_loss: 1.3845 - val_recon: 1.3845 - val_kl: 1.0188e-05
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2985 - val_loss: 1.3123 - val_recon: 1.3123 - val_kl: 6.3700e-06
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2840 - val_loss: 1.3158 - val_recon: 1.3158 - val_kl: 1.2798e-06
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2810 - val_loss: 1.3138 - val_recon: 1.3138 - val_kl: 3.8717e-06
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2793 - val_loss: 1.3132 - val_recon: 1.3132 - val_kl: 5.1750e-06
# Epoch 6/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2779 - val_loss: 1.3105 - val_recon: 1.3104 - val_kl: 5.6783e-06
# Epoch 7/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2771 - val_loss: 1.3099 - val_recon: 1.3099 - val_kl: 6.2182e-06
# Epoch 8/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2766 - val_loss: 1.3103 - val_recon: 1.3103 - val_kl: 7.7842e-06
# Epoch 9/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2760 - val_loss: 1.3087 - val_recon: 1.3087 - val_kl: 6.9642e-06
# Epoch 10/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2756 - val_loss: 1.3098 - val_recon: 1.3098 - val_kl: 6.9231e-06
# Epoch 11/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2751 - val_loss: 1.3066 - val_recon: 1.3066 - val_kl: 6.4766e-06
# Epoch 12/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2750 - val_loss: 1.3073 - val_recon: 1.3073 - val_kl: 7.5343e-06
# Epoch 13/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2747 - val_loss: 1.3071 - val_recon: 1.3071 - val_kl: 7.3243e-06
# Epoch 14/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2747 - val_loss: 1.3075 - val_recon: 1.3075 - val_kl: 7.6251e-06
# Epoch 15/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2744 - val_loss: 1.3067 - val_recon: 1.3067 - val_kl: 9.5383e-06
# Epoch 16/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2743 - val_loss: 1.3062 - val_recon: 1.3062 - val_kl: 1.0740e-05
# Epoch 17/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2743 - val_loss: 1.3057 - val_recon: 1.3057 - val_kl: 1.2392e-05
# Epoch 18/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2743 - val_loss: 1.3067 - val_recon: 1.3067 - val_kl: 1.2103e-05
# Epoch 19/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2741 - val_loss: 1.3070 - val_recon: 1.3070 - val_kl: 1.3000e-05
# Epoch 20/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2740 - val_loss: 1.3058 - val_recon: 1.3058 - val_kl: 1.1076e-05
# Epoch 21/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2741 - val_loss: 1.3067 - val_recon: 1.3067 - val_kl: 1.3724e-05
# Epoch 22/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2739 - val_loss: 1.3060 - val_recon: 1.3059 - val_kl: 1.4391e-05
# Epoch 23/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2738 - val_loss: 1.3056 - val_recon: 1.3056 - val_kl: 1.4708e-05
# Epoch 24/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2739 - val_loss: 1.3058 - val_recon: 1.3057 - val_kl: 1.4873e-05
# Epoch 25/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2738 - val_loss: 1.3052 - val_recon: 1.3052 - val_kl: 1.2891e-05
# Epoch 26/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2737 - val_loss: 1.3051 - val_recon: 1.3050 - val_kl: 1.3316e-05
# Epoch 27/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2736 - val_loss: 1.3047 - val_recon: 1.3046 - val_kl: 1.5446e-05
# Epoch 28/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2736 - val_loss: 1.3053 - val_recon: 1.3053 - val_kl: 1.6427e-05
# Epoch 29/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2736 - val_loss: 1.3059 - val_recon: 1.3059 - val_kl: 1.6057e-05
# Epoch 30/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2735 - val_loss: 1.3053 - val_recon: 1.3052 - val_kl: 1.9298e-05
# Epoch 31/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.2736 - val_loss: 1.3058 - val_recon: 1.3058 - val_kl: 1.9427e-05
# Epoch 32/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2735 - val_loss: 1.3053 - val_recon: 1.3053 - val_kl: 2.1747e-05
# Epoch 33/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.2734 - val_loss: 1.3038 - val_recon: 1.3038 - val_kl: 2.3403e-05
# Epoch 34/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.2734 - val_loss: 1.3054 - val_recon: 1.3054 - val_kl: 2.6030e-05
# Epoch 35/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.2733 - val_loss: 1.3040 - val_recon: 1.3040 - val_kl: 4.0156e-05
# Epoch 36/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.2734 - val_loss: 1.3058 - val_recon: 1.3058 - val_kl: 4.6196e-05
# Epoch 37/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.2734 - val_loss: 1.3045 - val_recon: 1.3045 - val_kl: 5.1900e-05
# Epoch 38/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2733 - val_loss: 1.3043 - val_recon: 1.3042 - val_kl: 6.4076e-05
# Epoch 39/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2731 - val_loss: 1.3051 - val_recon: 1.3050 - val_kl: 8.9200e-05
# Epoch 40/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.2732 - val_loss: 1.3036 - val_recon: 1.3034 - val_kl: 1.6007e-04
# Epoch 41/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2730 - val_loss: 1.3059 - val_recon: 1.3056 - val_kl: 3.1151e-04
# Epoch 42/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.2728 - val_loss: 1.3041 - val_recon: 1.3034 - val_kl: 7.0393e-04
# Epoch 43/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2614 - val_loss: 1.0899 - val_recon: 1.0602 - val_kl: 0.0297
# Epoch 44/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1556 - val_loss: 1.0542 - val_recon: 1.0096 - val_kl: 0.0446
# Epoch 45/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0997 - val_loss: 1.0131 - val_recon: 0.9717 - val_kl: 0.0414
# Epoch 46/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0858 - val_loss: 0.9956 - val_recon: 0.9499 - val_kl: 0.0457
# Epoch 47/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0784 - val_loss: 0.9561 - val_recon: 0.9135 - val_kl: 0.0426
# Epoch 48/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0470 - val_loss: 1.0051 - val_recon: 0.9651 - val_kl: 0.0400
# Epoch 49/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0359 - val_loss: 0.8981 - val_recon: 0.8542 - val_kl: 0.0439
# Epoch 50/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0120 - val_loss: 0.8703 - val_recon: 0.8128 - val_kl: 0.0575
# Epoch 51/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.9958 - val_loss: 0.8783 - val_recon: 0.8304 - val_kl: 0.0478
# Epoch 52/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.9792 - val_loss: 0.8379 - val_recon: 0.7885 - val_kl: 0.0493
# Epoch 53/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.9590 - val_loss: 0.8736 - val_recon: 0.8221 - val_kl: 0.0515
# Epoch 54/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.9244 - val_loss: 0.7876 - val_recon: 0.7388 - val_kl: 0.0488
# Epoch 55/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.9046 - val_loss: 0.7921 - val_recon: 0.7387 - val_kl: 0.0534
# Epoch 56/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.8873 - val_loss: 0.7672 - val_recon: 0.7116 - val_kl: 0.0557
# Epoch 57/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.8823 - val_loss: 0.7262 - val_recon: 0.6657 - val_kl: 0.0605
# Epoch 58/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8581 - val_loss: 0.6785 - val_recon: 0.6158 - val_kl: 0.0626
# Epoch 59/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.8386 - val_loss: 0.7551 - val_recon: 0.6922 - val_kl: 0.0629
# Epoch 60/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8269 - val_loss: 0.7087 - val_recon: 0.6467 - val_kl: 0.0620
# Epoch 61/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8185 - val_loss: 0.6848 - val_recon: 0.6214 - val_kl: 0.0634
# Epoch 62/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.8049 - val_loss: 0.6529 - val_recon: 0.5888 - val_kl: 0.0641
# Epoch 63/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.7940 - val_loss: 0.6127 - val_recon: 0.5439 - val_kl: 0.0688
# Epoch 64/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7898 - val_loss: 0.5634 - val_recon: 0.4902 - val_kl: 0.0732
# Epoch 65/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7762 - val_loss: 0.5773 - val_recon: 0.5053 - val_kl: 0.0720
# Epoch 66/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.7678 - val_loss: 0.5610 - val_recon: 0.4893 - val_kl: 0.0717
# Epoch 67/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.7605 - val_loss: 0.5643 - val_recon: 0.4880 - val_kl: 0.0762
# Epoch 68/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7556 - val_loss: 0.5851 - val_recon: 0.5027 - val_kl: 0.0824
# Epoch 69/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.7459 - val_loss: 0.5577 - val_recon: 0.4792 - val_kl: 0.0785
# Epoch 70/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.7461 - val_loss: 0.5309 - val_recon: 0.4493 - val_kl: 0.0816
# Epoch 71/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7265 - val_loss: 0.5580 - val_recon: 0.4803 - val_kl: 0.0777
# Epoch 72/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.7208 - val_loss: 0.5200 - val_recon: 0.4348 - val_kl: 0.0852
# Epoch 73/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7147 - val_loss: 0.5474 - val_recon: 0.4632 - val_kl: 0.0842
# Epoch 74/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.7032 - val_loss: 0.5256 - val_recon: 0.4414 - val_kl: 0.0842
# Epoch 75/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6973 - val_loss: 0.5032 - val_recon: 0.4215 - val_kl: 0.0817
# Epoch 76/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6955 - val_loss: 0.4773 - val_recon: 0.3914 - val_kl: 0.0859
# Epoch 77/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6958 - val_loss: 0.4759 - val_recon: 0.3845 - val_kl: 0.0913
# Epoch 78/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6879 - val_loss: 0.4380 - val_recon: 0.3466 - val_kl: 0.0913
# Epoch 79/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6839 - val_loss: 0.4676 - val_recon: 0.3751 - val_kl: 0.0925
# Epoch 80/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6806 - val_loss: 0.4885 - val_recon: 0.3966 - val_kl: 0.0919
# Epoch 81/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6650 - val_loss: 0.4789 - val_recon: 0.3861 - val_kl: 0.0929
# Epoch 82/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6614 - val_loss: 0.4205 - val_recon: 0.3257 - val_kl: 0.0948
# Epoch 83/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6556 - val_loss: 0.4443 - val_recon: 0.3496 - val_kl: 0.0947
# Epoch 84/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6539 - val_loss: 0.4503 - val_recon: 0.3543 - val_kl: 0.0960
# Epoch 85/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6457 - val_loss: 0.3941 - val_recon: 0.2959 - val_kl: 0.0983
# Epoch 86/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6386 - val_loss: 0.3696 - val_recon: 0.2704 - val_kl: 0.0993
# Epoch 87/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6397 - val_loss: 0.3819 - val_recon: 0.2825 - val_kl: 0.0994
# Epoch 88/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6409 - val_loss: 0.3853 - val_recon: 0.2776 - val_kl: 0.1077
# Epoch 89/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6354 - val_loss: 0.4238 - val_recon: 0.3203 - val_kl: 0.1035
# Epoch 90/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6215 - val_loss: 0.3649 - val_recon: 0.2586 - val_kl: 0.1063
# Epoch 91/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.6228 - val_loss: 0.3657 - val_recon: 0.2609 - val_kl: 0.1048
# Epoch 92/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6149 - val_loss: 0.4094 - val_recon: 0.3044 - val_kl: 0.1050
# Epoch 93/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6114 - val_loss: 0.3840 - val_recon: 0.2798 - val_kl: 0.1042
# Epoch 94/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6098 - val_loss: 0.3702 - val_recon: 0.2635 - val_kl: 0.1067
# Epoch 95/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6054 - val_loss: 0.3412 - val_recon: 0.2379 - val_kl: 0.1033
# Epoch 96/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6024 - val_loss: 0.3448 - val_recon: 0.2385 - val_kl: 0.1063
# Epoch 97/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6101 - val_loss: 0.3439 - val_recon: 0.2354 - val_kl: 0.1084
# Epoch 98/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6062 - val_loss: 0.3572 - val_recon: 0.2483 - val_kl: 0.1089
# Epoch 99/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6101 - val_loss: 0.3103 - val_recon: 0.1996 - val_kl: 0.1107
# Epoch 100/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6022 - val_loss: 0.3343 - val_recon: 0.2227 - val_kl: 0.1116
# Epoch 101/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.6067 - val_loss: 0.3375 - val_recon: 0.2222 - val_kl: 0.1153
# Epoch 102/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5953 - val_loss: 0.2957 - val_recon: 0.1819 - val_kl: 0.1138
# Epoch 103/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5921 - val_loss: 0.3465 - val_recon: 0.2330 - val_kl: 0.1135
# Epoch 104/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5866 - val_loss: 0.2938 - val_recon: 0.1815 - val_kl: 0.1122
# Epoch 105/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5827 - val_loss: 0.3149 - val_recon: 0.2000 - val_kl: 0.1149
# Epoch 106/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5788 - val_loss: 0.3450 - val_recon: 0.2332 - val_kl: 0.1118
# Epoch 107/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5861 - val_loss: 0.3391 - val_recon: 0.2276 - val_kl: 0.1115
# Epoch 108/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5934 - val_loss: 0.3237 - val_recon: 0.2069 - val_kl: 0.1168
# Epoch 109/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5784 - val_loss: 0.2893 - val_recon: 0.1743 - val_kl: 0.1150
# Epoch 110/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5817 - val_loss: 0.2908 - val_recon: 0.1713 - val_kl: 0.1195
# Epoch 111/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5758 - val_loss: 0.2772 - val_recon: 0.1597 - val_kl: 0.1176
# Epoch 112/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5826 - val_loss: 0.3005 - val_recon: 0.1841 - val_kl: 0.1165
# Epoch 113/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5721 - val_loss: 0.2936 - val_recon: 0.1743 - val_kl: 0.1193
# Epoch 114/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5734 - val_loss: 0.3826 - val_recon: 0.2629 - val_kl: 0.1197
# Epoch 115/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5798 - val_loss: 0.3422 - val_recon: 0.2232 - val_kl: 0.1190
# Epoch 116/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5687 - val_loss: 0.2689 - val_recon: 0.1485 - val_kl: 0.1204
# Epoch 117/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5671 - val_loss: 0.3326 - val_recon: 0.2090 - val_kl: 0.1236
# Epoch 118/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5708 - val_loss: 0.2928 - val_recon: 0.1715 - val_kl: 0.1212
# Epoch 119/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5813 - val_loss: 0.2554 - val_recon: 0.1334 - val_kl: 0.1220
# Epoch 120/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5752 - val_loss: 0.2624 - val_recon: 0.1403 - val_kl: 0.1221
# Epoch 121/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5658 - val_loss: 0.2579 - val_recon: 0.1357 - val_kl: 0.1222
# Epoch 122/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5635 - val_loss: 0.2759 - val_recon: 0.1506 - val_kl: 0.1252
# Epoch 123/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5587 - val_loss: 0.2865 - val_recon: 0.1607 - val_kl: 0.1258
# Epoch 124/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5751 - val_loss: 0.2625 - val_recon: 0.1352 - val_kl: 0.1273
# Epoch 125/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5706 - val_loss: 0.2951 - val_recon: 0.1682 - val_kl: 0.1269
# Epoch 126/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5732 - val_loss: 0.3131 - val_recon: 0.1863 - val_kl: 0.1267
# Epoch 127/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5585 - val_loss: 0.2758 - val_recon: 0.1480 - val_kl: 0.1277
# Epoch 128/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5633 - val_loss: 0.2996 - val_recon: 0.1748 - val_kl: 0.1248
# Epoch 129/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5732 - val_loss: 0.2665 - val_recon: 0.1419 - val_kl: 0.1245
# Epoch 130/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5629 - val_loss: 0.2695 - val_recon: 0.1440 - val_kl: 0.1255
# Epoch 131/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5666 - val_loss: 0.3155 - val_recon: 0.1864 - val_kl: 0.1290
# Epoch 132/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5613 - val_loss: 0.2688 - val_recon: 0.1414 - val_kl: 0.1275
# Epoch 133/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5621 - val_loss: 0.2080 - val_recon: 0.0803 - val_kl: 0.1277
# Epoch 134/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5617 - val_loss: 0.2846 - val_recon: 0.1558 - val_kl: 0.1287
# Epoch 135/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5595 - val_loss: 0.2540 - val_recon: 0.1257 - val_kl: 0.1284
# Epoch 136/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5570 - val_loss: 0.2564 - val_recon: 0.1283 - val_kl: 0.1280
# Epoch 137/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5629 - val_loss: 0.2818 - val_recon: 0.1532 - val_kl: 0.1285
# Epoch 138/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5592 - val_loss: 0.2499 - val_recon: 0.1219 - val_kl: 0.1280
# Epoch 139/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5602 - val_loss: 0.2536 - val_recon: 0.1317 - val_kl: 0.1219
# Epoch 140/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5606 - val_loss: 0.2544 - val_recon: 0.1264 - val_kl: 0.1280
# Epoch 141/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5599 - val_loss: 0.2767 - val_recon: 0.1485 - val_kl: 0.1282
# Epoch 142/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5672 - val_loss: 0.2955 - val_recon: 0.1680 - val_kl: 0.1275
# Epoch 143/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5570 - val_loss: 0.2533 - val_recon: 0.1246 - val_kl: 0.1286
# Epoch 144/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5581 - val_loss: 0.2741 - val_recon: 0.1477 - val_kl: 0.1264
# Epoch 145/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5694 - val_loss: 0.2773 - val_recon: 0.1503 - val_kl: 0.1269
# Epoch 146/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5661 - val_loss: 0.3333 - val_recon: 0.2063 - val_kl: 0.1270
# Epoch 147/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.5617 - val_loss: 0.2454 - val_recon: 0.1175 - val_kl: 0.1280
# Epoch 148/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5551 - val_loss: 0.2451 - val_recon: 0.1184 - val_kl: 0.1266
# Epoch 149/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5623 - val_loss: 0.2331 - val_recon: 0.1042 - val_kl: 0.1289
# Epoch 150/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5577 - val_loss: 0.2478 - val_recon: 0.1165 - val_kl: 0.1314
# Epoch 151/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.5544 - val_loss: 0.2966 - val_recon: 0.1708 - val_kl: 0.1258
# Epoch 152/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5577 - val_loss: 0.2828 - val_recon: 0.1532 - val_kl: 0.1296
# Epoch 153/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5559 - val_loss: 0.2760 - val_recon: 0.1484 - val_kl: 0.1276
# Epoch 154/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5591 - val_loss: 0.2681 - val_recon: 0.1382 - val_kl: 0.1300
# Epoch 155/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5526 - val_loss: 0.2736 - val_recon: 0.1457 - val_kl: 0.1279
# Epoch 156/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.5573 - val_loss: 0.2473 - val_recon: 0.1172 - val_kl: 0.1301
# Epoch 157/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5580 - val_loss: 0.2641 - val_recon: 0.1359 - val_kl: 0.1283
# Epoch 158/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.5551 - val_loss: 0.2689 - val_recon: 0.1383 - val_kl: 0.1305
# Epoch 159/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5590 - val_loss: 0.2749 - val_recon: 0.1433 - val_kl: 0.1315
# Epoch 160/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5655 - val_loss: 0.2634 - val_recon: 0.1348 - val_kl: 0.1286
# Epoch 161/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5622 - val_loss: 0.2748 - val_recon: 0.1455 - val_kl: 0.1294
# Epoch 162/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5601 - val_loss: 0.2574 - val_recon: 0.1274 - val_kl: 0.1301
# Epoch 163/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5537 - val_loss: 0.2715 - val_recon: 0.1423 - val_kl: 0.1292
# Epoch 164/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5559 - val_loss: 0.2746 - val_recon: 0.1464 - val_kl: 0.1282
# Epoch 165/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5572 - val_loss: 0.2239 - val_recon: 0.0949 - val_kl: 0.1290
# Epoch 166/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5705 - val_loss: 0.2517 - val_recon: 0.1229 - val_kl: 0.1288
# Epoch 167/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5579 - val_loss: 0.2764 - val_recon: 0.1474 - val_kl: 0.1290
# Epoch 168/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5520 - val_loss: 0.2841 - val_recon: 0.1544 - val_kl: 0.1297
# Epoch 169/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5567 - val_loss: 0.2152 - val_recon: 0.0865 - val_kl: 0.1288
# Epoch 170/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5578 - val_loss: 0.2310 - val_recon: 0.1025 - val_kl: 0.1285
# Epoch 171/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5627 - val_loss: 0.2471 - val_recon: 0.1164 - val_kl: 0.1307
# Epoch 172/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5513 - val_loss: 0.2597 - val_recon: 0.1304 - val_kl: 0.1293
# Epoch 173/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5492 - val_loss: 0.2323 - val_recon: 0.1034 - val_kl: 0.1289
# Epoch 174/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5538 - val_loss: 0.2672 - val_recon: 0.1370 - val_kl: 0.1303
# Epoch 175/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5501 - val_loss: 0.2500 - val_recon: 0.1204 - val_kl: 0.1297
# Epoch 176/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5492 - val_loss: 0.3244 - val_recon: 0.1943 - val_kl: 0.1301
# Epoch 177/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5571 - val_loss: 0.2388 - val_recon: 0.1083 - val_kl: 0.1305
# Epoch 178/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5554 - val_loss: 0.2912 - val_recon: 0.1621 - val_kl: 0.1290
# Epoch 179/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5635 - val_loss: 0.2463 - val_recon: 0.1106 - val_kl: 0.1357
# Epoch 180/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5550 - val_loss: 0.2593 - val_recon: 0.1295 - val_kl: 0.1298
# Epoch 181/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5501 - val_loss: 0.2427 - val_recon: 0.1109 - val_kl: 0.1318
# Epoch 182/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5603 - val_loss: 0.2301 - val_recon: 0.0986 - val_kl: 0.1314
# Epoch 183/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5607 - val_loss: 0.2396 - val_recon: 0.1109 - val_kl: 0.1287
# Epoch 184/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5505 - val_loss: 0.2619 - val_recon: 0.1298 - val_kl: 0.1321
# Epoch 185/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5594 - val_loss: 0.2408 - val_recon: 0.1116 - val_kl: 0.1292
# Epoch 186/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5525 - val_loss: 0.2291 - val_recon: 0.0986 - val_kl: 0.1305
# Epoch 187/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5571 - val_loss: 0.2261 - val_recon: 0.0968 - val_kl: 0.1293
# Epoch 188/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5559 - val_loss: 0.2533 - val_recon: 0.1220 - val_kl: 0.1313
# Epoch 189/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5506 - val_loss: 0.2502 - val_recon: 0.1195 - val_kl: 0.1307
# Epoch 190/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5499 - val_loss: 0.2426 - val_recon: 0.1141 - val_kl: 0.1285
# Epoch 191/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5521 - val_loss: 0.2468 - val_recon: 0.1192 - val_kl: 0.1276
# Epoch 192/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5497 - val_loss: 0.2793 - val_recon: 0.1494 - val_kl: 0.1299
# Epoch 193/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5600 - val_loss: 0.2940 - val_recon: 0.1660 - val_kl: 0.1281
# Epoch 194/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5521 - val_loss: 0.2309 - val_recon: 0.0990 - val_kl: 0.1318
# Epoch 195/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5503 - val_loss: 0.2566 - val_recon: 0.1259 - val_kl: 0.1307
# Epoch 196/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5530 - val_loss: 0.2422 - val_recon: 0.1115 - val_kl: 0.1306
# Epoch 197/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5553 - val_loss: 0.2320 - val_recon: 0.0983 - val_kl: 0.1337
# Epoch 198/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5601 - val_loss: 0.2148 - val_recon: 0.0824 - val_kl: 0.1324
# Epoch 199/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5558 - val_loss: 0.2464 - val_recon: 0.1166 - val_kl: 0.1298
# Epoch 200/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5564 - val_loss: 0.2631 - val_recon: 0.1341 - val_kl: 0.1290
# Epoch 201/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5460 - val_loss: 0.2817 - val_recon: 0.1519 - val_kl: 0.1299
# Epoch 202/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5489 - val_loss: 0.2403 - val_recon: 0.1117 - val_kl: 0.1286
# Epoch 203/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5535 - val_loss: 0.2720 - val_recon: 0.1410 - val_kl: 0.1311
# Epoch 204/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5515 - val_loss: 0.2161 - val_recon: 0.0854 - val_kl: 0.1307
# Epoch 205/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5446 - val_loss: 0.2644 - val_recon: 0.1360 - val_kl: 0.1284
# Epoch 206/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5496 - val_loss: 0.2924 - val_recon: 0.1646 - val_kl: 0.1278
# Epoch 207/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5609 - val_loss: 0.2156 - val_recon: 0.0865 - val_kl: 0.1291
# Epoch 208/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5527 - val_loss: 0.2488 - val_recon: 0.1171 - val_kl: 0.1317
# Epoch 209/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5556 - val_loss: 0.2459 - val_recon: 0.1166 - val_kl: 0.1293
# Epoch 210/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5492 - val_loss: 0.2225 - val_recon: 0.0947 - val_kl: 0.1278
# Epoch 211/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5523 - val_loss: 0.2333 - val_recon: 0.1056 - val_kl: 0.1276
# Epoch 212/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5532 - val_loss: 0.2757 - val_recon: 0.1464 - val_kl: 0.1292
# Epoch 213/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5530 - val_loss: 0.2526 - val_recon: 0.1219 - val_kl: 0.1308
# Epoch 214/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5505 - val_loss: 0.2594 - val_recon: 0.1294 - val_kl: 0.1300
# Epoch 215/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5544 - val_loss: 0.3020 - val_recon: 0.1719 - val_kl: 0.1301
# Epoch 216/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5571 - val_loss: 0.2445 - val_recon: 0.1138 - val_kl: 0.1307
# Epoch 217/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5488 - val_loss: 0.2433 - val_recon: 0.1139 - val_kl: 0.1294
# Epoch 218/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5482 - val_loss: 0.2149 - val_recon: 0.0842 - val_kl: 0.1308
# Epoch 219/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5536 - val_loss: 0.2373 - val_recon: 0.1095 - val_kl: 0.1278
# Epoch 220/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5513 - val_loss: 0.2931 - val_recon: 0.1631 - val_kl: 0.1300
# Epoch 221/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5602 - val_loss: 0.2804 - val_recon: 0.1492 - val_kl: 0.1311
# Epoch 222/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5496 - val_loss: 0.2993 - val_recon: 0.1693 - val_kl: 0.1300
# Epoch 223/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5477 - val_loss: 0.2479 - val_recon: 0.1180 - val_kl: 0.1299
# Epoch 224/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5526 - val_loss: 0.3004 - val_recon: 0.1703 - val_kl: 0.1301
# Epoch 225/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5475 - val_loss: 0.2418 - val_recon: 0.1138 - val_kl: 0.1280
# Epoch 226/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5544 - val_loss: 0.2533 - val_recon: 0.1247 - val_kl: 0.1286
# Epoch 227/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5529 - val_loss: 0.2444 - val_recon: 0.1183 - val_kl: 0.1261
# Epoch 228/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5574 - val_loss: 0.2567 - val_recon: 0.1274 - val_kl: 0.1293
# Epoch 229/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5573 - val_loss: 0.2597 - val_recon: 0.1306 - val_kl: 0.1291
# Epoch 230/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5530 - val_loss: 0.2424 - val_recon: 0.1086 - val_kl: 0.1338
# Epoch 231/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5586 - val_loss: 0.2304 - val_recon: 0.1003 - val_kl: 0.1301
# Epoch 232/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5425 - val_loss: 0.2579 - val_recon: 0.1298 - val_kl: 0.1280
# Epoch 233/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5542 - val_loss: 0.2054 - val_recon: 0.0738 - val_kl: 0.1315
# Epoch 234/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5560 - val_loss: 0.2300 - val_recon: 0.0945 - val_kl: 0.1355
# Epoch 235/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5591 - val_loss: 0.2785 - val_recon: 0.1443 - val_kl: 0.1342
# Epoch 236/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5516 - val_loss: 0.3341 - val_recon: 0.2068 - val_kl: 0.1273
# Epoch 237/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5532 - val_loss: 0.2217 - val_recon: 0.0894 - val_kl: 0.1323
# Epoch 238/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5548 - val_loss: 0.2294 - val_recon: 0.0983 - val_kl: 0.1310
# Epoch 239/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5478 - val_loss: 0.2553 - val_recon: 0.1249 - val_kl: 0.1303
# Epoch 240/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5510 - val_loss: 0.2259 - val_recon: 0.0947 - val_kl: 0.1311
# Epoch 241/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5429 - val_loss: 0.2302 - val_recon: 0.1015 - val_kl: 0.1287
# Epoch 242/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5465 - val_loss: 0.2175 - val_recon: 0.0907 - val_kl: 0.1268
# Epoch 243/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5472 - val_loss: 0.2441 - val_recon: 0.1128 - val_kl: 0.1313
# Epoch 244/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5498 - val_loss: 0.2389 - val_recon: 0.1067 - val_kl: 0.1321
# Epoch 245/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5528 - val_loss: 0.1947 - val_recon: 0.0631 - val_kl: 0.1316
# Epoch 246/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5511 - val_loss: 0.2989 - val_recon: 0.1691 - val_kl: 0.1298
# Epoch 247/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5528 - val_loss: 0.2526 - val_recon: 0.1216 - val_kl: 0.1310
# Epoch 248/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5503 - val_loss: 0.2398 - val_recon: 0.1103 - val_kl: 0.1295
# Epoch 249/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5519 - val_loss: 0.3422 - val_recon: 0.2115 - val_kl: 0.1307
# Epoch 250/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5497 - val_loss: 0.2422 - val_recon: 0.1135 - val_kl: 0.1288
# Epoch 251/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5517 - val_loss: 0.2430 - val_recon: 0.1132 - val_kl: 0.1298
# Epoch 252/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5515 - val_loss: 0.2589 - val_recon: 0.1295 - val_kl: 0.1294
# Epoch 253/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5513 - val_loss: 0.2768 - val_recon: 0.1471 - val_kl: 0.1297
# Epoch 254/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5595 - val_loss: 0.2394 - val_recon: 0.1076 - val_kl: 0.1318
# Epoch 255/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5476 - val_loss: 0.2323 - val_recon: 0.1051 - val_kl: 0.1273
# Epoch 256/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5544 - val_loss: 0.2421 - val_recon: 0.1109 - val_kl: 0.1312
# Epoch 257/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5560 - val_loss: 0.2573 - val_recon: 0.1272 - val_kl: 0.1301
# Epoch 258/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5578 - val_loss: 0.2347 - val_recon: 0.1025 - val_kl: 0.1322
# Epoch 259/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5504 - val_loss: 0.2745 - val_recon: 0.1465 - val_kl: 0.1281
# Epoch 260/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5539 - val_loss: 0.2044 - val_recon: 0.0733 - val_kl: 0.1311
# Epoch 261/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5493 - val_loss: 0.2425 - val_recon: 0.1142 - val_kl: 0.1283
# Epoch 262/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5524 - val_loss: 0.2603 - val_recon: 0.1331 - val_kl: 0.1272
# Epoch 263/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5436 - val_loss: 0.2383 - val_recon: 0.1080 - val_kl: 0.1303
# Epoch 264/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5533 - val_loss: 0.2225 - val_recon: 0.0940 - val_kl: 0.1285
# Epoch 265/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5545 - val_loss: 0.2386 - val_recon: 0.1075 - val_kl: 0.1312
# Epoch 266/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5515 - val_loss: 0.2288 - val_recon: 0.0989 - val_kl: 0.1298
# Epoch 267/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5539 - val_loss: 0.3178 - val_recon: 0.1886 - val_kl: 0.1291
# Epoch 268/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5492 - val_loss: 0.2798 - val_recon: 0.1478 - val_kl: 0.1320
# Epoch 269/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5483 - val_loss: 0.2353 - val_recon: 0.1040 - val_kl: 0.1314
# Epoch 270/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5472 - val_loss: 0.2367 - val_recon: 0.1062 - val_kl: 0.1304
# Epoch 271/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5562 - val_loss: 0.2303 - val_recon: 0.0975 - val_kl: 0.1328
# Epoch 272/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5433 - val_loss: 0.2306 - val_recon: 0.1022 - val_kl: 0.1284
# Epoch 273/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5504 - val_loss: 0.1991 - val_recon: 0.0648 - val_kl: 0.1344
# Epoch 274/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5439 - val_loss: 0.2363 - val_recon: 0.1077 - val_kl: 0.1287
# Epoch 275/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5548 - val_loss: 0.3017 - val_recon: 0.1721 - val_kl: 0.1296
# Epoch 276/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5595 - val_loss: 0.2412 - val_recon: 0.1069 - val_kl: 0.1343
# Epoch 277/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5509 - val_loss: 0.2520 - val_recon: 0.1213 - val_kl: 0.1307
# Epoch 278/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5520 - val_loss: 0.2683 - val_recon: 0.1398 - val_kl: 0.1285
# Epoch 279/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5460 - val_loss: 0.2724 - val_recon: 0.1404 - val_kl: 0.1320
# Epoch 280/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5489 - val_loss: 0.2039 - val_recon: 0.0756 - val_kl: 0.1283
# Epoch 281/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5502 - val_loss: 0.2445 - val_recon: 0.1139 - val_kl: 0.1306
# Epoch 282/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5513 - val_loss: 0.3000 - val_recon: 0.1693 - val_kl: 0.1306
# Epoch 283/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5615 - val_loss: 0.3393 - val_recon: 0.2109 - val_kl: 0.1284
# Epoch 284/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5466 - val_loss: 0.2399 - val_recon: 0.1110 - val_kl: 0.1289
# Epoch 285/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5501 - val_loss: 0.2950 - val_recon: 0.1619 - val_kl: 0.1331
# Epoch 286/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5576 - val_loss: 0.2906 - val_recon: 0.1585 - val_kl: 0.1321
# Epoch 287/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5630 - val_loss: 0.2772 - val_recon: 0.1419 - val_kl: 0.1352
# Epoch 288/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5617 - val_loss: 0.2408 - val_recon: 0.1089 - val_kl: 0.1319
# Epoch 289/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5557 - val_loss: 0.2181 - val_recon: 0.0878 - val_kl: 0.1302
# Epoch 290/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5488 - val_loss: 0.2406 - val_recon: 0.1075 - val_kl: 0.1331
# Epoch 291/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5467 - val_loss: 0.2227 - val_recon: 0.0913 - val_kl: 0.1314
# Epoch 292/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5453 - val_loss: 0.2331 - val_recon: 0.1060 - val_kl: 0.1271
# Epoch 293/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5502 - val_loss: 0.2464 - val_recon: 0.1155 - val_kl: 0.1309
# Epoch 294/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5474 - val_loss: 0.2150 - val_recon: 0.0841 - val_kl: 0.1309
# Epoch 295/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5515 - val_loss: 0.2718 - val_recon: 0.1391 - val_kl: 0.1327
# Epoch 296/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5517 - val_loss: 0.2697 - val_recon: 0.1397 - val_kl: 0.1300
# Epoch 297/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5427 - val_loss: 0.2514 - val_recon: 0.1226 - val_kl: 0.1289
# Epoch 298/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5451 - val_loss: 0.2257 - val_recon: 0.0953 - val_kl: 0.1304
# Epoch 299/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5472 - val_loss: 0.2513 - val_recon: 0.1205 - val_kl: 0.1308
# Epoch 300/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5492 - val_loss: 0.2721 - val_recon: 0.1419 - val_kl: 0.1302
# Epoch 301/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5469 - val_loss: 0.2694 - val_recon: 0.1401 - val_kl: 0.1293
# Epoch 302/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5516 - val_loss: 0.2381 - val_recon: 0.1076 - val_kl: 0.1305
# Epoch 303/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5539 - val_loss: 0.2275 - val_recon: 0.0951 - val_kl: 0.1324
# Epoch 304/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5468 - val_loss: 0.2383 - val_recon: 0.1034 - val_kl: 0.1349
# Epoch 305/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5549 - val_loss: 0.2222 - val_recon: 0.0897 - val_kl: 0.1325
# Epoch 306/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5490 - val_loss: 0.2406 - val_recon: 0.1099 - val_kl: 0.1307
# Epoch 307/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5513 - val_loss: 0.2335 - val_recon: 0.1039 - val_kl: 0.1297
# Epoch 308/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5471 - val_loss: 0.2342 - val_recon: 0.1044 - val_kl: 0.1298
# Epoch 309/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5439 - val_loss: 0.2623 - val_recon: 0.1323 - val_kl: 0.1300
# Epoch 310/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5512 - val_loss: 0.2662 - val_recon: 0.1362 - val_kl: 0.1300
# Epoch 311/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5481 - val_loss: 0.3065 - val_recon: 0.1755 - val_kl: 0.1310
# Epoch 312/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5479 - val_loss: 0.2827 - val_recon: 0.1578 - val_kl: 0.1249
# Epoch 313/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5430 - val_loss: 0.3016 - val_recon: 0.1754 - val_kl: 0.1261
# Epoch 314/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5452 - val_loss: 0.2751 - val_recon: 0.1464 - val_kl: 0.1287
# Epoch 315/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5528 - val_loss: 0.1848 - val_recon: 0.0507 - val_kl: 0.1340
# Epoch 316/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5470 - val_loss: 0.2330 - val_recon: 0.1031 - val_kl: 0.1300
# Epoch 317/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5492 - val_loss: 0.2309 - val_recon: 0.1012 - val_kl: 0.1297
# Epoch 318/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5586 - val_loss: 0.2321 - val_recon: 0.0997 - val_kl: 0.1324
# Epoch 319/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5508 - val_loss: 0.2934 - val_recon: 0.1622 - val_kl: 0.1313
# Epoch 320/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5546 - val_loss: 0.3417 - val_recon: 0.2084 - val_kl: 0.1334
# Epoch 321/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5514 - val_loss: 0.2669 - val_recon: 0.1374 - val_kl: 0.1296
# Epoch 322/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5523 - val_loss: 0.2517 - val_recon: 0.1231 - val_kl: 0.1286
# Epoch 323/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5465 - val_loss: 0.2511 - val_recon: 0.1202 - val_kl: 0.1309
# Epoch 324/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5558 - val_loss: 0.2533 - val_recon: 0.1247 - val_kl: 0.1286
# Epoch 325/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5464 - val_loss: 0.2510 - val_recon: 0.1214 - val_kl: 0.1296
# Epoch 326/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5509 - val_loss: 0.2113 - val_recon: 0.0802 - val_kl: 0.1311
# Epoch 327/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5588 - val_loss: 0.2354 - val_recon: 0.1050 - val_kl: 0.1304
# Epoch 328/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5475 - val_loss: 0.2374 - val_recon: 0.1085 - val_kl: 0.1289
# Epoch 329/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5445 - val_loss: 0.2359 - val_recon: 0.1068 - val_kl: 0.1291
# Epoch 330/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5498 - val_loss: 0.2455 - val_recon: 0.1156 - val_kl: 0.1299
# Epoch 331/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5447 - val_loss: 0.2469 - val_recon: 0.1177 - val_kl: 0.1292
# Epoch 332/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5407 - val_loss: 0.2309 - val_recon: 0.1031 - val_kl: 0.1278
# Epoch 333/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5520 - val_loss: 0.2615 - val_recon: 0.1288 - val_kl: 0.1327
# Epoch 334/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5539 - val_loss: 0.2049 - val_recon: 0.0717 - val_kl: 0.1332
# Epoch 335/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5472 - val_loss: 0.2010 - val_recon: 0.0702 - val_kl: 0.1307
# Epoch 336/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5428 - val_loss: 0.2131 - val_recon: 0.0805 - val_kl: 0.1326
# Epoch 337/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5582 - val_loss: 0.3151 - val_recon: 0.1834 - val_kl: 0.1317
# Epoch 338/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5663 - val_loss: 0.2392 - val_recon: 0.1088 - val_kl: 0.1303
# Epoch 339/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5541 - val_loss: 0.2229 - val_recon: 0.0909 - val_kl: 0.1320
# Epoch 340/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5504 - val_loss: 0.2483 - val_recon: 0.1169 - val_kl: 0.1315
# Epoch 341/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5439 - val_loss: 0.2502 - val_recon: 0.1197 - val_kl: 0.1305
# Epoch 342/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5507 - val_loss: 0.3112 - val_recon: 0.1796 - val_kl: 0.1316
# Epoch 343/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5516 - val_loss: 0.2106 - val_recon: 0.0830 - val_kl: 0.1276
# Epoch 344/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5489 - val_loss: 0.2455 - val_recon: 0.1144 - val_kl: 0.1311
# Epoch 345/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5497 - val_loss: 0.2716 - val_recon: 0.1414 - val_kl: 0.1303
# Epoch 346/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5489 - val_loss: 0.2295 - val_recon: 0.0999 - val_kl: 0.1296
# Epoch 347/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5408 - val_loss: 0.2303 - val_recon: 0.1015 - val_kl: 0.1288
# Epoch 348/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5488 - val_loss: 0.3350 - val_recon: 0.2063 - val_kl: 0.1287
# Epoch 349/500
# ...
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5456 - val_loss: 0.2876 - val_recon: 0.1569 - val_kl: 0.1306
# Epoch 375/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5492 - val_loss: 0.2552 - val_recon: 0.1267 - val_kl: 0.1285
# Epoch 376/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5438 - val_loss: 0.2575 - val_recon: 0.1267 - val_kl: 0.1308
# Epoch 377/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5491 - val_loss: 0.2769 - val_recon: 0.1449 - val_kl: 0.1320
# Epoch 378/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5467 - val_loss: 0.2495 - val_recon: 0.1161 - val_kl: 0.1334
# Epoch 379/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5537 - val_loss: 0.2864 - val_recon: 0.1576 - val_kl: 0.1288
# Epoch 380/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5449 - val_loss: 0.2531 - val_recon: 0.1240 - val_kl: 0.1291
# Epoch 381/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5455 - val_loss: 0.2112 - val_recon: 0.0786 - val_kl: 0.1326
# Epoch 382/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5501 - val_loss: 0.2688 - val_recon: 0.1371 - val_kl: 0.1318
# Epoch 383/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5484 - val_loss: 0.2469 - val_recon: 0.1141 - val_kl: 0.1328
# Epoch 384/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.5510 - val_loss: 0.2461 - val_recon: 0.1156 - val_kl: 0.1305
# Epoch 385/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5489 - val_loss: 0.2122 - val_recon: 0.0798 - val_kl: 0.1324
# Epoch 386/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5474 - val_loss: 0.2173 - val_recon: 0.0849 - val_kl: 0.1324
# Epoch 387/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5459 - val_loss: 0.2235 - val_recon: 0.0922 - val_kl: 0.1313
# Epoch 388/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5438 - val_loss: 0.2648 - val_recon: 0.1327 - val_kl: 0.1321
# Epoch 389/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5440 - val_loss: 0.2784 - val_recon: 0.1472 - val_kl: 0.1312
# Epoch 390/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5497 - val_loss: 0.2440 - val_recon: 0.1100 - val_kl: 0.1340
# Epoch 391/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5437 - val_loss: 0.2373 - val_recon: 0.1074 - val_kl: 0.1299
# Epoch 392/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5430 - val_loss: 0.2067 - val_recon: 0.0736 - val_kl: 0.1330
# Epoch 393/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5416 - val_loss: 0.2384 - val_recon: 0.1100 - val_kl: 0.1284
# Epoch 394/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5445 - val_loss: 0.2558 - val_recon: 0.1271 - val_kl: 0.1287
# Epoch 395/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5507 - val_loss: 0.2217 - val_recon: 0.0890 - val_kl: 0.1327
# Epoch 396/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5502 - val_loss: 0.2386 - val_recon: 0.1086 - val_kl: 0.1299
# Epoch 397/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5489 - val_loss: 0.2519 - val_recon: 0.1199 - val_kl: 0.1320
# Epoch 398/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5511 - val_loss: 0.2364 - val_recon: 0.1049 - val_kl: 0.1316
# Epoch 399/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5482 - val_loss: 0.2601 - val_recon: 0.1287 - val_kl: 0.1314
# Epoch 400/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5541 - val_loss: 0.2284 - val_recon: 0.0989 - val_kl: 0.1295
# Epoch 401/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5411 - val_loss: 0.2249 - val_recon: 0.0944 - val_kl: 0.1305
# Epoch 402/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5471 - val_loss: 0.2339 - val_recon: 0.1037 - val_kl: 0.1301
# Epoch 403/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5517 - val_loss: 0.2470 - val_recon: 0.1167 - val_kl: 0.1302
# Epoch 404/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5506 - val_loss: 0.2911 - val_recon: 0.1604 - val_kl: 0.1308
# Epoch 405/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5434 - val_loss: 0.2352 - val_recon: 0.1064 - val_kl: 0.1288
# Epoch 406/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5453 - val_loss: 0.1836 - val_recon: 0.0495 - val_kl: 0.1341
# Epoch 407/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5500 - val_loss: 0.2742 - val_recon: 0.1430 - val_kl: 0.1311
# Epoch 408/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5449 - val_loss: 0.2384 - val_recon: 0.1103 - val_kl: 0.1281
# Epoch 409/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5517 - val_loss: 0.2233 - val_recon: 0.0946 - val_kl: 0.1287
# Epoch 410/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5483 - val_loss: 0.2708 - val_recon: 0.1399 - val_kl: 0.1309
# Epoch 411/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5482 - val_loss: 0.2773 - val_recon: 0.1450 - val_kl: 0.1323
# Epoch 412/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5470 - val_loss: 0.2076 - val_recon: 0.0746 - val_kl: 0.1330
# Epoch 413/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5460 - val_loss: 0.2980 - val_recon: 0.1695 - val_kl: 0.1285
# Epoch 414/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5474 - val_loss: 0.2507 - val_recon: 0.1220 - val_kl: 0.1288
# Epoch 415/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5462 - val_loss: 0.2566 - val_recon: 0.1280 - val_kl: 0.1286
# Epoch 416/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5526 - val_loss: 0.2765 - val_recon: 0.1449 - val_kl: 0.1316
# Epoch 417/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5538 - val_loss: 0.2337 - val_recon: 0.1031 - val_kl: 0.1306
# Epoch 418/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5469 - val_loss: 0.2983 - val_recon: 0.1666 - val_kl: 0.1317
# Epoch 419/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5495 - val_loss: 0.2472 - val_recon: 0.1147 - val_kl: 0.1325
# Epoch 420/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5504 - val_loss: 0.2358 - val_recon: 0.1054 - val_kl: 0.1304
# Epoch 421/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5474 - val_loss: 0.2823 - val_recon: 0.1490 - val_kl: 0.1333
# Epoch 422/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5498 - val_loss: 0.2296 - val_recon: 0.1024 - val_kl: 0.1272
# Epoch 423/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5475 - val_loss: 0.2719 - val_recon: 0.1369 - val_kl: 0.1351
# Epoch 424/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5435 - val_loss: 0.2633 - val_recon: 0.1344 - val_kl: 0.1289
# Epoch 425/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5440 - val_loss: 0.2184 - val_recon: 0.0912 - val_kl: 0.1272
# Epoch 426/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5478 - val_loss: 0.2572 - val_recon: 0.1258 - val_kl: 0.1314
# Epoch 427/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5555 - val_loss: 0.2276 - val_recon: 0.0995 - val_kl: 0.1281
# Epoch 428/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5507 - val_loss: 0.2601 - val_recon: 0.1317 - val_kl: 0.1285
# Epoch 429/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5470 - val_loss: 0.2403 - val_recon: 0.1091 - val_kl: 0.1312
# Epoch 430/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5457 - val_loss: 0.1877 - val_recon: 0.0587 - val_kl: 0.1290
# Epoch 431/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5460 - val_loss: 0.2245 - val_recon: 0.0942 - val_kl: 0.1302
# Epoch 432/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5428 - val_loss: 0.2307 - val_recon: 0.0994 - val_kl: 0.1314
# Epoch 433/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5522 - val_loss: 0.3444 - val_recon: 0.2174 - val_kl: 0.1269
# Epoch 434/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5424 - val_loss: 0.2417 - val_recon: 0.1135 - val_kl: 0.1282
# Epoch 435/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5472 - val_loss: 0.2394 - val_recon: 0.1052 - val_kl: 0.1342
# Epoch 436/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5520 - val_loss: 0.2809 - val_recon: 0.1535 - val_kl: 0.1274
# Epoch 437/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5530 - val_loss: 0.2417 - val_recon: 0.1093 - val_kl: 0.1324
# Epoch 438/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5430 - val_loss: 0.2070 - val_recon: 0.0755 - val_kl: 0.1315
# Epoch 439/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5477 - val_loss: 0.2306 - val_recon: 0.0987 - val_kl: 0.1319
# Epoch 440/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5399 - val_loss: 0.2611 - val_recon: 0.1285 - val_kl: 0.1326
# Epoch 441/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5445 - val_loss: 0.2693 - val_recon: 0.1369 - val_kl: 0.1324
# Epoch 442/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5430 - val_loss: 0.2715 - val_recon: 0.1409 - val_kl: 0.1306
# Epoch 443/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5453 - val_loss: 0.2113 - val_recon: 0.0808 - val_kl: 0.1306
# Epoch 444/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5535 - val_loss: 0.2784 - val_recon: 0.1459 - val_kl: 0.1325
# Epoch 445/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5610 - val_loss: 0.2807 - val_recon: 0.1537 - val_kl: 0.1269
# Epoch 446/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5462 - val_loss: 0.2335 - val_recon: 0.1036 - val_kl: 0.1299
# Epoch 447/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5466 - val_loss: 0.2240 - val_recon: 0.0941 - val_kl: 0.1299
# Epoch 448/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5456 - val_loss: 0.2172 - val_recon: 0.0819 - val_kl: 0.1353
# Epoch 449/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5477 - val_loss: 0.2058 - val_recon: 0.0743 - val_kl: 0.1315
# Epoch 450/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.5462 - val_loss: 0.2147 - val_recon: 0.0846 - val_kl: 0.1301
# Epoch 451/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5459 - val_loss: 0.2505 - val_recon: 0.1198 - val_kl: 0.1307
# Epoch 452/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5451 - val_loss: 0.2709 - val_recon: 0.1412 - val_kl: 0.1297
# Epoch 453/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5540 - val_loss: 0.2239 - val_recon: 0.0919 - val_kl: 0.1320
# Epoch 454/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5498 - val_loss: 0.2101 - val_recon: 0.0773 - val_kl: 0.1327
# Epoch 455/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5475 - val_loss: 0.2760 - val_recon: 0.1443 - val_kl: 0.1317
# Epoch 456/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5501 - val_loss: 0.2776 - val_recon: 0.1476 - val_kl: 0.1300
# Epoch 457/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5473 - val_loss: 0.2625 - val_recon: 0.1319 - val_kl: 0.1305
# Epoch 458/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5494 - val_loss: 0.2764 - val_recon: 0.1456 - val_kl: 0.1308
# Epoch 459/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5507 - val_loss: 0.2493 - val_recon: 0.1189 - val_kl: 0.1304
# Epoch 460/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5458 - val_loss: 0.2553 - val_recon: 0.1265 - val_kl: 0.1289
# Epoch 461/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5444 - val_loss: 0.2476 - val_recon: 0.1189 - val_kl: 0.1287
# Epoch 462/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5470 - val_loss: 0.2446 - val_recon: 0.1124 - val_kl: 0.1322
# Epoch 463/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5407 - val_loss: 0.2449 - val_recon: 0.1150 - val_kl: 0.1299
# Epoch 464/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5422 - val_loss: 0.2783 - val_recon: 0.1475 - val_kl: 0.1308
# Epoch 465/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5440 - val_loss: 0.2274 - val_recon: 0.0988 - val_kl: 0.1286
# Epoch 466/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5478 - val_loss: 0.2222 - val_recon: 0.0936 - val_kl: 0.1286
# Epoch 467/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5453 - val_loss: 0.2620 - val_recon: 0.1309 - val_kl: 0.1311
# Epoch 468/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5483 - val_loss: 0.2600 - val_recon: 0.1275 - val_kl: 0.1325
# Epoch 469/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5563 - val_loss: 0.2184 - val_recon: 0.0876 - val_kl: 0.1309
# Epoch 470/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5404 - val_loss: 0.3063 - val_recon: 0.1784 - val_kl: 0.1279
# Epoch 471/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5514 - val_loss: 0.2199 - val_recon: 0.0872 - val_kl: 0.1327
# Epoch 472/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5444 - val_loss: 0.2198 - val_recon: 0.0867 - val_kl: 0.1331
# Epoch 473/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5406 - val_loss: 0.1965 - val_recon: 0.0637 - val_kl: 0.1328
# Epoch 474/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5497 - val_loss: 0.2287 - val_recon: 0.0945 - val_kl: 0.1343
# Epoch 475/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5461 - val_loss: 0.2487 - val_recon: 0.1195 - val_kl: 0.1292
# Epoch 476/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5452 - val_loss: 0.2833 - val_recon: 0.1520 - val_kl: 0.1313
# Epoch 477/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5409 - val_loss: 0.2200 - val_recon: 0.0899 - val_kl: 0.1301
# Epoch 478/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5449 - val_loss: 0.2550 - val_recon: 0.1219 - val_kl: 0.1331
# Epoch 479/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5406 - val_loss: 0.3167 - val_recon: 0.1885 - val_kl: 0.1282
# Epoch 480/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5453 - val_loss: 0.2592 - val_recon: 0.1305 - val_kl: 0.1287
# Epoch 481/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5487 - val_loss: 0.2410 - val_recon: 0.1097 - val_kl: 0.1313
# Epoch 482/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5416 - val_loss: 0.2372 - val_recon: 0.1087 - val_kl: 0.1285
# Epoch 483/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5536 - val_loss: 0.2572 - val_recon: 0.1257 - val_kl: 0.1315
# Epoch 484/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5440 - val_loss: 0.2833 - val_recon: 0.1551 - val_kl: 0.1282
# Epoch 485/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5436 - val_loss: 0.2431 - val_recon: 0.1157 - val_kl: 0.1273
# Epoch 486/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5467 - val_loss: 0.2255 - val_recon: 0.0947 - val_kl: 0.1308
# Epoch 487/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5466 - val_loss: 0.2467 - val_recon: 0.1152 - val_kl: 0.1315
# Epoch 488/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5485 - val_loss: 0.2468 - val_recon: 0.1197 - val_kl: 0.1271
# Epoch 489/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5434 - val_loss: 0.2829 - val_recon: 0.1492 - val_kl: 0.1337
# Epoch 490/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5464 - val_loss: 0.2740 - val_recon: 0.1420 - val_kl: 0.1320
# Epoch 491/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5534 - val_loss: 0.2589 - val_recon: 0.1243 - val_kl: 0.1345
# Epoch 492/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5448 - val_loss: 0.2714 - val_recon: 0.1400 - val_kl: 0.1314
# Epoch 493/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5440 - val_loss: 0.2516 - val_recon: 0.1186 - val_kl: 0.1330
# Epoch 494/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5404 - val_loss: 0.2507 - val_recon: 0.1228 - val_kl: 0.1279
# Epoch 495/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5520 - val_loss: 0.2353 - val_recon: 0.1042 - val_kl: 0.1312
# Epoch 496/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5474 - val_loss: 0.2614 - val_recon: 0.1277 - val_kl: 0.1337
# Epoch 497/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5463 - val_loss: 0.2482 - val_recon: 0.1185 - val_kl: 0.1296
# Epoch 498/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5443 - val_loss: 0.2894 - val_recon: 0.1610 - val_kl: 0.1285
# Epoch 499/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5477 - val_loss: 0.2248 - val_recon: 0.0940 - val_kl: 0.1309
# Epoch 500/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5465 - val_loss: 0.2872 - val_recon: 0.1552 - val_kl: 0.1321
# noise emission sigma:  0.26578453
# Reconstruction loss:  0.08595465
# KL loss:              3.53292
# Total loss:           3.6188745

# %% [markdown]
# ## Generating new data

# %%
# %matplotlib notebook

os.makedirs('data/processed', exist_ok=True)
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
vae = VAE(encoder=encoder, decoder=decoder)
vae.compile()

gen_dataset = data.values # convert to tensors
gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32)

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)

# set figure size
plt.figure(figsize=(15, 5))
# boxplot of encoded_mean
plt.subplot(1, 2, 1)
plt.boxplot(encoded_mean.numpy().reshape(-1, latent_filter))
plt.title('Encoded Mean')

# boxplot of encoded_log_var
plt.subplot(1, 2, 2)
plt.boxplot(encoded_log_var.numpy().reshape(-1, latent_filter))
plt.title('Encoded Log Variance')

plt.savefig("images/encoded_log_variance.png", dpi=300)

start_date = '1970-01-01 00:00:00'
end_date = '2020-12-31 16:00:00' 
dt = pd.date_range(start=start_date, end=end_date, freq='h')

n_latents = int(np.ceil(len(dt) / LATENT_SIZE))
z_gen = np.random.normal(size=(1, n_latents, latent_filter)).astype(np.float32)
gen_mean = decoder(z_gen).numpy()

# Add noise (optional, commented out)
noise = np.random.normal(size=gen_mean.shape) * np.exp(0.5 * vae.noise_log_var[0].numpy())
gen = gen_mean + noise
gen = gen_mean  # without noise

data_params = pd.read_csv('data/data_params.csv', index_col=0)
offset = data_params.loc['offset', 'values']
scale = data_params.loc['scale', 'values']

gen_series = pd.Series(gen[0, :len(dt)]*scale + offset, index=dt)
gen_series = gen_series.rename('temperature')
gen_series = gen_series.to_frame()
gen_series.index.name = 'time'

# Add back seasonal cycle
df_obs = pd.read_csv('data/processed/observed_time_series.csv', index_col=0, parse_dates=True)
df_obs['weekofyear'] = df_obs.index.isocalendar().week
weekly_climatology = df_obs.groupby('weekofyear')['Observed'].mean()

# Map each hour in generated time series to its weekly mean
week_numbers = gen_series.index.isocalendar().week
seasonal_cycle = np.array([weekly_climatology[w] for w in week_numbers])
gen_series['temperature'] += seasonal_cycle

gen_series.to_csv('data/processed/generated.csv')

print(f"Succesfully generated time series of length: {len(gen_series.iloc[:,0])}")

gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')
plt.savefig('images/generated_monthly_avg.png', dpi=300)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 1536)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1536, 1)   │          0 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_24 (Conv1D)  │ (None, 512, 20)   │        120 │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_25 (Conv1D)  │ (None, 256, 20)   │      1,220 │ conv1d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_26 (Conv1D)  │ (None, 128, 20)   │      1,220 │ conv1d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_27 (Conv1D)  │ (None, 64, 20)    │      1,220 │ conv1d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_28 (Conv1D)  │ (None, 32, 20)    │      1,220 │ conv1d_27[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_29 (Conv1D)  │ (None, 16, 40)    │      2,440 │ conv1d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 16, 20)    │          0 │ conv1d_29[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_9          │ (None, 16, 20)    │          0 │ conv1d_29[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_4          │ (None, 16, 20)    │          0 │ get_item_8[0][0], │
# │ (Sampling)          │                   │            │ get_item_9[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,440 (29.06 KB)
#  Trainable params: 7,440 (29.06 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, None, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_24             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_25             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_26             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_27             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_28             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_29             │ (None, None, 1)        │           101 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_9 (Reshape)             │ (None, None)           │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,201 (24.22 KB)
#  Trainable params: 6,201 (24.22 KB)
#  Non-trainable params: 0 (0.00 B)
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# <div id='2c6620df-8d46-4acb-8fef-9415894689aa'></div>
# Succesfully generated time series of length: 447065
# C:\Users\lokes\AppData\Local\Temp\ipykernel_1452\1574129440.py:84: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   gen_series['temperature'].resample('M').mean().plot(title='Monthly Mean of Generated Series')

# %% [markdown]
# ### Latent Space Analysis

# %%
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

# To demonstrate loading, create a new instance and load weights
encoder = build_encoder()
decoder = build_decoder()
vae = VAE(encoder=encoder, decoder=decoder)
# optimizer = Adam(learning_rate=learning_rate)
vae.compile()

#------------------------------------------------------------------------------
gen_dataset = data.values
gen_dataset_tensor = tf.convert_to_tensor(gen_dataset, dtype=tf.float32) # convert to tensors
#------------------------------------------------------------------------------

# Call the model once to build it
dummy_input = tf.zeros((1, gen_dataset.shape[1]), dtype=tf.float32)  # shape (1, 1536)
_ = vae(dummy_input)
vae.load_weights('model/model_weights.weights.h5')

encoded_mean, encoded_log_var, encoded_z = encoder(gen_dataset_tensor)

# Save latent vectors
latent_vectors = encoded_mean.numpy()  # Shape: (num_samples, latent_dim, latent_filter)
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)  # Flatten for saving

# Save as CSV
latent_df = pd.DataFrame(flat_latents)
latent_df.index = data.index[:len(latent_df)]  # Optional: align with input time series
latent_df.to_csv("data/processed/latent_vectors.csv")

# Save as .npy for quick load
np.save("data/processed/latent_vectors.npy", latent_vectors)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 1536)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 1536, 1)   │          0 │ input_layer_10[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_30 (Conv1D)  │ (None, 512, 20)   │        120 │ reshape_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_31 (Conv1D)  │ (None, 256, 20)   │      1,220 │ conv1d_30[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_32 (Conv1D)  │ (None, 128, 20)   │      1,220 │ conv1d_31[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_33 (Conv1D)  │ (None, 64, 20)    │      1,220 │ conv1d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_34 (Conv1D)  │ (None, 32, 20)    │      1,220 │ conv1d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_35 (Conv1D)  │ (None, 16, 40)    │      2,440 │ conv1d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_10         │ (None, 16, 20)    │          0 │ conv1d_35[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_11         │ (None, 16, 20)    │          0 │ conv1d_35[0][0]   │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_5          │ (None, 16, 20)    │          0 │ get_item_10[0][0… │
# │ (Sampling)          │                   │            │ get_item_11[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,440 (29.06 KB)
#  Trainable params: 7,440 (29.06 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, None, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_30             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_31             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_32             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_33             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_34             │ (None, None, 20)       │         1,220 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_35             │ (None, None, 1)        │           101 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_11 (Reshape)            │ (None, None)           │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,201 (24.22 KB)
#  Trainable params: 6,201 (24.22 KB)
#  Non-trainable params: 0 (0.00 B)
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Latent Space Plotting Stuff

# %%
# %matplotlib notebook

# Setup
os.makedirs('images', exist_ok=True)

# Load data
latent_vectors = np.load("data/processed/latent_vectors.npy")
data = pd.read_csv('data/processed/phoenix_64days.csv', index_col=0, parse_dates=True)
data.index = pd.to_datetime(data.index, format='mixed')

if latent_vectors.shape[0] != data.shape[0]:
    print(f"Mismatch: {latent_vectors.shape[0]} latent vectors vs {data.shape[0]} rows in CSV. Trimming data.")
    data = data.iloc[:latent_vectors.shape[0]]

# Colour labels
mean_temps = data.mean(axis=1)
day_of_year_frac = data.index.dayofyear / 365.0
hour_of_day_frac = data.index.hour / 24.0

# Flatten latent vectors
flat_latents = latent_vectors.reshape(latent_vectors.shape[0], -1)

# Reduce dimensions
print("First performing a PCA")
pca = PCA(n_components=2)
pca_latents = pca.fit_transform(flat_latents)
print("PCA done")

print("Now performing t-SNE")
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_latents = tsne.fit_transform(flat_latents)
print("t-SNE done")

print("Now performing UMAP")
umap_model = umap.UMAP(n_components=2, random_state=42)
umap_latents = umap_model.fit_transform(flat_latents)
print("UMAP done")

# Helper for plotting
colorings = {
    "Mean Temp": mean_temps,
    "Day of Year (Fraction)": day_of_year_frac,
    "Hour of Day (Fraction)": hour_of_day_frac
}

reduced_spaces = {
    "Raw": flat_latents,
    "PCA": pca_latents,
    "t-SNE": tsne_latents,
    "UMAP": umap_latents
}

# Plot
fig, axs = plt.subplots(4, 3, figsize=(18, 20))

# Define colormaps for each coloring
cmap_dict = {
    "Mean Temp": "coolwarm",
    "Day of Year (Fraction)": "viridis",
    "Hour of Day (Fraction)": "plasma"
}

for i, (method_name, embedding) in enumerate(reduced_spaces.items()):
    for j, (label_name, label_values) in enumerate(colorings.items()):
        print(f"Plotting {method_name} coloured by {label_name}")
        ax = axs[i, j]
        cmap = cmap_dict.get(label_name, "viridis")
        scatter = ax.scatter(embedding[:, 0], embedding[:, 1], c=label_values, cmap=cmap, s=8, alpha=0.7)
        ax.set_title(f"{method_name} - Coloured by {label_name}")
        ax.set_xticks([])
        ax.set_yticks([])
        fig.colorbar(scatter, ax=ax, fraction=0.03, pad=0.01)

plt.tight_layout()
plt.savefig("images/latent_space_analysis.png", dpi=500)
plt.close()
print("Saved mega plot to images/latent_space_analysis.png")
# Out:
# First performing a PCA
# PCA done
# Now performing t-SNE
# t-SNE done
# Now performing UMAP
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP done
# <div id='6bd107a7-998e-4edb-be45-6bd2e2b73912'></div>
# Plotting Raw coloured by Mean Temp
# Plotting Raw coloured by Day of Year (Fraction)
# Plotting Raw coloured by Hour of Day (Fraction)
# Plotting PCA coloured by Mean Temp
# Plotting PCA coloured by Day of Year (Fraction)
# Plotting PCA coloured by Hour of Day (Fraction)
# Plotting t-SNE coloured by Mean Temp
# Plotting t-SNE coloured by Day of Year (Fraction)
# Plotting t-SNE coloured by Hour of Day (Fraction)
# Plotting UMAP coloured by Mean Temp
# Plotting UMAP coloured by Day of Year (Fraction)
# Plotting UMAP coloured by Hour of Day (Fraction)
# Saved mega plot to images/latent_space_analysis.png

# %% [markdown]
# ## Wrap up

# %%
# Define paths
folders_to_move = [
    'images',
    'model',
    os.path.join('data', 'processed')
]

files_to_move = [
    os.path.join('data', 'data_params.csv'),
    os.path.join('data', 'train_summary.csv')
]

# Create the results directory if it doesn't exist
os.makedirs(results_directory, exist_ok=True)

# Move folders
for folder in folders_to_move:
    if os.path.isdir(folder):
        dest_folder = os.path.join(results_directory, os.path.basename(folder))
        shutil.move(folder, dest_folder)
        print(f"Moved folder '{folder}' to '{dest_folder}'")
    else:
        print(f"Folder not found: {folder}")

# Move files
for file in files_to_move:
    if os.path.isfile(file):
        dest_file = os.path.join(results_directory, os.path.basename(file))
        shutil.move(file, dest_file)
        print(f"Moved file '{file}' to '{dest_file}'")
    else:
        print(f"File not found: {file}")
# Out:
# Moved folder 'images' to 'summary/training_run_Normal_prior_False_phase_shift_500_epochs\images'
# Moved folder 'model' to 'summary/training_run_Normal_prior_False_phase_shift_500_epochs\model'
# Moved folder 'data\processed' to 'summary/training_run_Normal_prior_False_phase_shift_500_epochs\processed'
# Moved file 'data\data_params.csv' to 'summary/training_run_Normal_prior_False_phase_shift_500_epochs\data_params.csv'
# Moved file 'data\train_summary.csv' to 'summary/training_run_Normal_prior_False_phase_shift_500_epochs\train_summary.csv'
